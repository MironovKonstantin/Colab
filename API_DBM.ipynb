# %% [markdown]
# <a href="https://colab.research.google.com/github/MironovKonstantin/Colab/blob/main/API_DBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Установка библиотек

# %%
# Определение объема модулей интеграции
SCAN_MODUL = True
GOOGLE_DISK = True
PARSING = False

# %%
import logging

# %% [markdown]
# ## Импорт библиотек для работы с Google Drive

# %%
#@title Установка модулей Google Drive
if GOOGLE_DISK:
    from google.colab import drive
    drive.mount('/content/drive')
    import pickle
# Out:
# Mounted at /content/drive

# %%
#@title Импорт библиотек для парсинга Норникель
import requests
import json
from datetime import datetime
from html import unescape

# %%
#@title Импорт библиотек для работы с PurchaseFiles
# !pip install rarfile
# !pip install py7zr


import os # Для работы с файловой системой
import zipfile # распаковка файлов (архивов)
import rarfile # распаковка файлов (архивов)
import py7zr # распаковка файлов (архивов)

import shutil # Для операций над файлами и директориями.
# Out:
# Collecting rarfile
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.0
# Collecting py7zr
#   Downloading py7zr-0.20.6-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 1.5 MB/s eta 0:00:00
# Collecting texttable (from py7zr)
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.6.6 (from py7zr)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.0 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4 (from py7zr)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 34.1 MB/s eta 0:00:00
# Collecting pyppmd<1.1.0,>=0.18.1 (from py7zr)
#   Downloading pyppmd-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 15.4 MB/s eta 0:00:00
# Collecting pybcj>=0.6.0 (from py7zr)
#   Downloading pybcj-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 4.5 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting brotli>=1.0.9 (from py7zr)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 70.8 MB/s eta 0:00:00
# Collecting inflate64>=0.3.1 (from py7zr)
#   Downloading inflate64-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr) (5.9.5)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr
# Successfully installed brotli-1.0.9 inflate64-0.3.1 multivolumefile-0.2.3 py7zr-0.20.6 pybcj-1.0.1 pycryptodomex-3.18.0 pyppmd-1.0.0 pyzstd-0.15.9 texttable-1.6.7

# %% [markdown]
# ## 0.1 Импорт библиотек для работы с Документами

# %%
#@title Импорт библиотек для работы с содержанием файлов
if SCAN_MODUL:
    # !pip install pytesseract # для работы с pdf
    # !pip install pdf2image # для работы с pdf
    # !apt-get install unoconv # Для преобразования документа в pdf
    # !apt-get install -y poppler-utils # Для работы с распознованием pdf файла
    # !apt-get install -y tesseract-ocr # движок, используемый для распознавания текста из изображений
    # !apt install tesseract-ocr # пакет распознования OCR
    # !apt install tesseract-ocr-rus # поддержка русского
    # !apt install tesseract-ocr-eng # поддержка английского
# !pip install --upgrade pytesseract pdf2image
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (9.4.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-opensymbol
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libcdr-0.1-1
#   libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1 libeot0
#   libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfreehand-0.1-1 libgpgme11 libgpgmepp6 libharfbuzz-icu0 libhunspell-1.7-0
#   libhyphen0 liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1
#   libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice-base-core libreoffice-calc libreoffice-common libreoffice-core
#   libreoffice-draw libreoffice-impress libreoffice-math
#   libreoffice-style-colibre libreoffice-writer librevenge-0.0-0
#   libsuitesparseconfig5 libtext-iconv-perl libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libvisio-0.1-1 libwpd-0.10-10 libwpg-0.3-3
#   libwps-0.4-4 libxmlsec1 libxmlsec1-nss libyajl2 lp-solve poppler-data
#   python3-uno uno-libs-private ure
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ispell | aspell | hunspell wordlist
#   hunspell openoffice.org-hunspell | openoffice.org-core raptor2-utils
#   rasqal-utils librdf-storage-postgresql librdf-storage-mysql
#   librdf-storage-sqlite librdf-storage-virtuoso redland-utils libreoffice-base
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav bluez
#   fonts-crosextra-caladea fonts-crosextra-carlito libreoffice-java-common
#   default-jre | java8-runtime | jre poppler-utils ghostscript
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   apparmor dictionaries-common fonts-liberation2 fonts-opensymbol
#   hunspell-en-us libabsl20210324 libabw-0.1-1 libcdr-0.1-1
#   libclucene-contribs1v5 libclucene-core1v5 libcolamd2 libe-book-0.1-1 libeot0
#   libepubgen-0.1-1 libetonyek-0.1-1 libexttextcat-2.0-0 libexttextcat-data
#   libfreehand-0.1-1 libgpgme11 libgpgmepp6 libharfbuzz-icu0 libhunspell-1.7-0
#   libhyphen0 liblangtag-common liblangtag1 libmhash2 libmspub-0.1-1
#   libmwaw-0.3-3 libmythes-1.2-0 libodfgen-0.1-1 liborcus-0.17-0
#   liborcus-parser-0.17-0 libpagemaker-0.0-0 libraptor2-0 librasqal3 librdf0
#   libreoffice-base-core libreoffice-calc libreoffice-common libreoffice-core
#   libreoffice-draw libreoffice-impress libreoffice-math
#   libreoffice-style-colibre libreoffice-writer librevenge-0.0-0
#   libsuitesparseconfig5 libtext-iconv-perl libuno-cppu3
#   libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libvisio-0.1-1 libwpd-0.10-10 libwpg-0.3-3
#   libwps-0.4-4 libxmlsec1 libxmlsec1-nss libyajl2 lp-solve poppler-data
#   python3-uno uno-libs-private unoconv ure
# 0 upgraded, 66 newly installed, 0 to remove and 16 not upgraded.
# Need to get 107 MB of archives.
# After this operation, 373 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.2 [595 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation2 all 2.1.5-1 [1,614 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-opensymbol all 2:102.12+LibO7.3.7-0ubuntu0.22.04.3 [102 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabsl20210324 amd64 0~20210324.2-2 [387 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu7 [209 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libabw-0.1-1 amd64 0.1.3-1build3 [102 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdr-0.1-1 amd64 0.1.6-2build2 [392 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [530 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1ubuntu5 [96.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag-common all 0.6.3-2ubuntu1 [193 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblangtag1 amd64 0.6.3-2ubuntu1 [53.8 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libe-book-0.1-1 amd64 0.1.3-2build2 [148 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libeot0 amd64 0.01-5build2 [28.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu5 [120 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libetonyek-0.1-1 amd64 0.1.10-3build1 [637 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-data all 3.4.5-1build2 [179 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1build2 [13.7 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfreehand-0.1-1 amd64 0.1.2-3build2 [272 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgme11 amd64 1.16.0-1.2ubuntu4.1 [136 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgpgmepp6 amd64 1.16.0-1.2ubuntu4.1 [109 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.1 [5,886 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmhash2 amd64 0.9.9.9-9build2 [95.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspub-0.1-1 amd64 0.1.4-3build3 [144 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmwaw-0.3-3 amd64 0.3.21-1build1 [2,375 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmythes-1.2-0 amd64 2:1.2.4-4build1 [9,352 B]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libodfgen-0.1-1 amd64 0.1.8-2build2 [245 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-parser-0.17-0 amd64 0.17.2-2 [107 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborcus-0.17-0 amd64 0.17.2-2 [393 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build3 [55.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libyajl2 amd64 2.1.0-3build2 [20.6 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu4 [172 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 librasqal3 amd64 0.9.33-0.2ubuntu1 [193 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 librdf0 amd64 1.0.17-1.1ubuntu3 [106 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-style-colibre all 1:7.3.7-0ubuntu0.22.04.3 [1,293 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-sal3 amd64 1:7.3.7-0ubuntu0.22.04.3 [196 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.3 [17.0 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppu3 amd64 1:7.3.7-0ubuntu0.22.04.3 [87.8 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 uno-libs-private amd64 1:7.3.7-0ubuntu0.22.04.3 [232 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.3 [344 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:7.3.7-0ubuntu0.22.04.3 [15.8 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ure amd64 1:7.3.7-0ubuntu0.22.04.3 [1,312 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-common all 1:7.3.7-0ubuntu0.22.04.3 [23.4 MB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1 amd64 1.2.33-1build2 [139 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmlsec1-nss amd64 1.2.33-1build2 [67.7 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-core amd64 1:7.3.7-0ubuntu0.22.04.3 [40.4 MB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-base-core amd64 1:7.3.7-0ubuntu0.22.04.3 [973 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 lp-solve amd64 5.5.2.5-2build2 [315 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwps-0.4-4 amd64 0.4.12-2build1 [812 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-calc amd64 1:7.3.7-0ubuntu0.22.04.3 [8,426 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisio-0.1-1 amd64 0.1.7-1build5 [238 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpd-0.10-10 amd64 0.10.3-2build1 [209 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwpg-0.3-3 amd64 0.3.3-1build3 [49.9 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-draw amd64 1:7.3.7-0ubuntu0.22.04.3 [3,228 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-impress amd64 1:7.3.7-0ubuntu0.22.04.3 [1,360 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-math amd64 1:7.3.7-0ubuntu0.22.04.3 [596 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libreoffice-writer amd64 1:7.3.7-0ubuntu0.22.04.3 [10.3 MB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-uno amd64 1:7.3.7-0ubuntu0.22.04.3 [148 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 unoconv all 0.7-2ubuntu1 [46.7 kB]
# Fetched 107 MB in 9s (11.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package poppler-data.
# (Reading database ... 120893 files and directories currently installed.)
# Preparing to unpack .../00-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../01-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../02-apparmor_3.0.4-2ubuntu2.2_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.2) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../03-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../04-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-opensymbol.
# Preparing to unpack .../05-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.3_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../06-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../07-libabsl20210324_0~20210324.2-2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../08-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../09-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../10-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../11-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../12-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../13-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../14-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../15-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../16-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../17-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../18-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../19-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../20-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../21-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../22-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../23-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../24-libgpgme11_1.16.0-1.2ubuntu4.1_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.1) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../25-libgpgmepp6_1.16.0-1.2ubuntu4.1_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../26-libharfbuzz-icu0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../27-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../28-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../29-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../30-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../31-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../32-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../33-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../34-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../35-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../36-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../37-libyajl2_2.1.0-3build2_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3build2) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../38-libraptor2-0_2.0.15-0ubuntu4_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../39-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../40-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../41-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.3_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../42-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../43-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../44-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../45-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../46-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../47-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../48-ure_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../49-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.3_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../50-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../51-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../52-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../53-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../54-lp-solve_5.5.2.5-2build2_amd64.deb ...
# Unpacking lp-solve (5.5.2.5-2build2) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../55-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../56-libreoffice-calc_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-calc (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../57-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../58-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../59-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../60-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../61-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../62-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../63-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../64-python3-uno_1%3a7.3.7-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.3) ...
# Selecting previously unselected package unoconv.
# Preparing to unpack .../65-unoconv_0.7-2ubuntu1_all.deb ...
# Unpacking unoconv (0.7-2ubuntu1) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libyajl2:amd64 (2.1.0-3build2) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.1) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up apparmor (3.0.4-2ubuntu2.2) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.3) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.1) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4) ...
# Setting up lp-solve (5.5.2.5-2build2) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.3) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-calc (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/calc.xcd with new version
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.3) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Setting up unoconv (0.7-2ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.2 [186 kB]
# Fetched 186 kB in 0s (832 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 125985 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.2_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (13.9 MB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 126015 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-rus
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,271 kB of archives.
# After this operation, 3,877 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-rus all 1:4.00~git30-7274cfa-1.1 [1,271 kB]
# Fetched 1,271 kB in 0s (4,564 kB/s)
# Selecting previously unselected package tesseract-ocr-rus.
# (Reading database ... 126062 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-rus_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-rus (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-rus (1:4.00~git30-7274cfa-1.1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-eng is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-eng set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.10)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (1.16.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)

# %%
#@title Установка Chat GPT
# !pip install openai # поддержка Chat GPT

import openai

openai.api_key = "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"
# Out:
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.28.0

# %% [markdown]
# ## Импорт библиотек для работы с DBM API

# %%
# !pip install pytz

from datetime import datetime
import pytz

# Получаем часовой пояс GMT+7
timezone = pytz.timezone('Asia/Bangkok')
# Out:
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2023.3)

# %% [markdown]
# ## Тестовые модули

# %%
#@title Модули для парсинга интернет страниц
if PARSING:
    # !pip install selenium
    # !apt-get update # to update ubuntu to correctly run apt install
    # !apt install -y chromium-chromedriver
    # !cp /usr/lib/chromium-browser/chromedriver /usr/bin
    import sys
    sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

    from selenium import webdriver
    from bs4 import BeautifulSoup
    import time

    # !pip install webdriver-manager

# %% [markdown]
# # 2 Объявление классов

# %%
#@title Объявление глобальных констант

# %%
#@title Объявление логгеров
"""
NOTSET: Уровень логирования не установлен явно и будет использоваться уровень родительского логгера, если он есть.
DEBUG: Самый низкий уровень. Используется для детального вывода отладочной информации.
INFO: Информационный уровень. Используется для вывода основной информации о ходе выполнения программы.
WARNING: Предупреждение. Используется для сообщений о потенциальных проблемах, которые не приводят к ошибке.
ERROR: Уровень ошибки. Используется для сообщений о реальных ошибках в программе.
CRITICAL: Критический уровень. Используется для сообщений о критических ошибках, которые могут привести к аварийному завершению программы.
"""

import logging

class DBM_Logger(logging.Logger):
    def __init__(self, name, custom_formatter, level, filter=None):
        super().__init__(name)

        custom_handler = logging.StreamHandler()
        custom_handler.setFormatter(custom_formatter)
        custom_handler.setLevel(level)
        if filter:
            custom_handler.addFilter(filter)
        self.addHandler(custom_handler)

# Настройки для отладки
formatter_debag = logging.Formatter('%(name)s(%(levelname)s) %(funcName)s: %(message)s')
filter_debag = (lambda record: record.funcName == '_answergpt_with_api')  # Фильтр
level_debug = logging.DEBUG
# Логгеры для отладки
api_deb = DBM_Logger('API_DEBUG', formatter_debag, level_debug, filter_debag) # Логгер DEBUG сообщений LLM
llm_llm = DBM_Logger('LLM_TO_LLM', formatter_debag, level_debug, filter_debag) # Логгер для отображения сообщий обменивающихся между LLM
doc_deb = DBM_Logger('DOC_DEBUG', formatter_debag, level_debug, filter_debag) # Логгер для классов документов (сущностей с данными)
db_deb = DBM_Logger('DB_DEBUG', formatter_debag, level_debug, filter_debag) # Логгер для базы данных
crm_deb = DBM_Logger('CRM_DEBUG', formatter_debag, level_debug, filter_debag) # Логгер для CRM
# Настройки для пользователей
formatter_user = logging.Formatter('%(asctime)s Нейросеть: %(message)s', '%d.%m.%y %H:%M')
level_user = logging.INFO
# Логгеры для пользователей
log_user = DBM_Logger('TO_USER', formatter_user, level_user) # Логгер для отображения сообщий обменивающихся между LLM

def test():
    # Пример логирования
    doc_deb.info("Это сообщение уровня INFO ")

    # Пример после изменения настроек хэндлера
    api_deb.debug("Это сообщение уровня DEBUG")

test()

# %%
#@title Объявление класса TenderId для выдачи номеров тендеров

class TenderId:
    current = 10000  # Константа класса для начального номера

    @classmethod
    def next(cls):
        """Получение следующего номера закупки."""
        cls.current += 1  # Увеличиваем счетчик на 1
        return cls.current  # Возвращаем новый номер

# %%
#@title Объявление класса NornickelTender для парсинга сайта Норникеля
class NornickelTender:
    def __init__(self, data):
        self.id = TenderId.next()
        self.name = data.get('name', 'Н/Д')
        active_to_unix = data.get('activeTo', None)
        self.active_to = datetime.utcfromtimestamp(int(active_to_unix)).strftime('%d.%m.%Y') if active_to_unix else 'Н/Д'
        self.method = data.get('method', {}).get('value', 'Н/Д')
        self.customer = data.get('customer', {}).get('value', 'Н/Д')
        self.address = data.get('address', {}).get('value', 'Н/Д')
        self.organizer = unescape(data.get('organizer', {}).get('value', 'Н/Д'))
        self.email = data.get('email', {}).get('value', 'Н/Д')
        self.phone = data.get('phone', {}).get('value', 'Н/Д')
        self.application_method = data.get('applicationMethod', {}).get('value', 'Н/Д')
        self.documentation_link = "https://www.nornickel.ru" + data.get('documentation', {}).get('link', 'Н/Д')
        self.documentation_type = data.get('documentation', {}).get('type', 'Н/Д')
        self.files_urls = []
        self.files_urls.append(self.documentation_link)
        self.documents = {} # Словарь документов класса Documents, с уникальным идентификатором Documents.name

# %%
#@title Объявление класса CRMTender для парсинга сайта Норникеля
class CRMTender:
    def __init__(self, tender):
        self.id = tender.id
        self.name = tender.name # Название тендера
        self.submission_date = tender.active_to # Дата подачи заявки
        self.method = tender.method
        self.customer = tender.customer
        self.address = tender.address
        self.organizer = tender.organizer
        self.email = tender.email
        self.phone = tender.phone
        self.application_method = tender.application_method
        self.documentation_link = tender.documentation_link
        self.documentation_type = tender.documentation_type
        self.files_urls = tender.files_urls
        self.documents = tender.documents # Словарь документов key - Document.name, value - Document()

# %%
#@title Объявление класса PurchaseFiles для работы с файлами каждой закупки

class PurchaseFiles:
    def __init__(self, tender):
        self.tender = tender
        self.name = tender.name
        self.id = tender.id
        self.files_urls = tender.files_urls
        self.files = []  # Список для хранения списка загруженных файлов
        self.unpackfiles = [] # Список для хранения разархивированных (обработанных) файлов
        self.folders = {} # Словарь для хранения путей к папкам UnPack, Spec, Temp, UnPackTemp
        self.specification_file_path = [] # Список - путь к файлам спецификации
        self.specification = [] # Содержание файлов спецификаций
        self.content = {} # Словарь контента
        self.view_levels = ["Поверхностный", "Стандартный", "Детальный"] # Тип проверки содержания файла

        self.folders["URL"] = os.path.join("Downloads", str(self.id), "URL")
        self.folders["UnPackTemp"] = os.path.join("Downloads", str(self.id), "UnPackTemp")
        self.folders["UnPack"] = os.path.join("Downloads", str(self.id), "UnPack")
        self.folders["Temp"] = os.path.join("Downloads", str(self.id), "Temp")

# %%
#@title Объявление класса Documents для работы с содержанием файлов

class Document:
    SYSTEM_ROLES = {} # Двухуровневый словарь - описание Ролей системы для LLM.

    def __init__(self, tender_id, name, file_path):
        if tender_id is None:
            raise ValueError("Не заполнено поле tender_id")
        if file_path is None:
            raise ValueError("Не заполнено поле file_path")

        self.tender_id = tender_id
        self.name = name
        self.file_path = file_path  # Путь файла
        self.folders = {} # Служебные папки
        self.content = None # Контент (содержание) документа
        self.number_of_parts = 0 # Количество частей документа
        self.token_limit = 4000  # Максимальное количество токенов для одного запроса в нейросеть
        self.part_limit = 10  # Максимальное количество частей, которые будут проверены
        self.overloaded = False
        self.content_parts = [] # Контент (содержание) документа, разделенный на части (для совместимости с количеством токенов,
        # которые может прожевать нейросеть в один запрос)
        self.upgrade_content_parts = [] # Улучшенное (содержание) частей документа (для плохо отсканированных документов)
        self.is_specification = None # Документ является спецификацией
        self.view_levels = ["Поверхностный", "Стандартный", "Детальный"] # Тип проверки содержания документа
        self.view_level = None # Текущий уровень проверки
        self.about_content = None # Осмысленное описание контента (о чем документ)
        self.about_parts = [] # Осмысленное описание каждой части контента
        #Структруируется по Названию роли и по номеру версии описания.

        self.folders["Temp"] = os.path.join("Downloads", str(tender_id), "Temp")

# %%
#@title Объявление класса DataBase для работы с Google Drive
class DataBase:
    def __init__(self, file_path):
        self.NornickelTender_db = {}
        self.PurchaseFiles_db = {}
        self.Document_db = {}
        self.CRMTender_db = {}
        self.file_path = file_path

        if os.path.getsize(self.file_path) > 0:  # Проверка на пустоту файла
            with open(self.file_path, 'rb') as input_file:
                try:
                    database = pickle.load(input_file)
                    self.NornickelTender_db = database.get('NornickelTender_db', {})
                    self.PurchaseFiles_db = database.get('PurchaseFiles_db', {})
                    self.Document_db = database.get('Document_db', {})
                except EOFError:
                    db_deb.warning("Ошибка: файл пуст или данные повреждены.")
        else:
            db_deb.warning("Файл пуст, используются стандартные значения.")

    @classmethod
    def create_file(cls, file_path):
        with open(file_path, 'wb') as f:
            pickle.dump({}, f)  # Сохраняем пустой словарь, а не оставляем файл пустым


DataBase.create_file('/content/drive/My Drive/CRM_DataBase.pkl')
CRM = DataBase('/content/drive/My Drive/CRM_DataBase.pkl')

# %%
# CRM.erase()

# %%
#@title Объявление класса API_DBM
class API_DBM:
    class_functions = {} # Все API функции класса
    system_roles = {} # Роли передаваемые в параметр system в запросе Chat GPT
    user_roles = {}
    class_api_rules = {} # Каталог описания API запросов для GPT
    func_names = [] # Список имен всех функций класса
    func_message = {} # Сообщение пользователю, которое отправляется при успешном вызове обработки API-запроса
    func_desc = {} # Описание функции для принятия решения LLM
    func_result = {} # Результат, возвращаемый функцией для принятия решения LLM

    def __init__(self, function_names=[], aviable=True, level=0):
        self.inf_for_user = {} # Сопутствующие методу данные, для использования, анализа, передачи пользователю
        self.messages = [] # История переписки
        self.system_basic = {"role": "system", "content": API_DBM.system_roles["BOT_HELPER_WITH_API"]}
        self.available_api = {}
        self.level = level + 1 #Уровень вложенности класса в рекурсивном методе вызова
        self.user_goal = None
        self.current_system # Текущее системное сообщение

        if function_names:
            for function_name in list(API_DBM.class_api_rules.keys()):
                if (aviable and function_name in function_names) or (not aviable and function_name not in function_names):
                    self.available_api[function_name] = API_DBM.class_api_rules[function_name]
                    api_deb.debug(f"API_DBM: __init__: Параметры: {function_names},{aviable}. Результат function_name {function_name} is aviable: {aviable}")

# %% [markdown]
# # Объявление методов

# %% [markdown]
# ## 1 Методы парсинга сайта Норникель класса NornickelTender

# %%
#@title Метод создания класса PurchaseFiles из класса NornickelTender

def create_purchase_files(self):
    doc_deb.debug(self.files_urls)
    purchasefiles = PurchaseFiles(self)
    return purchasefiles

NornickelTender.create_purchase_files = create_purchase_files

# %%
#@title Метод отображения информации о тендере

def display(self):
    log_user.info(f"Найден тендер с именем: {self.name}")
    log_user.info(f"Активно до: {self.active_to}")
    log_user.info(f"Метод: {self.method}")
    log_user.info(f"Заказчик: {self.customer}")
    log_user.info(f"Адрес: {self.address}")
    log_user.info(f"Организатор: {self.organizer}")
    log_user.info(f"Email: {self.email}")
    log_user.info(f"Телефон: {self.phone}")
    log_user.info(f"Метод подачи заявки: {self.application_method}")
    log_user.info(f"Документация: {self.documentation_link}")
    log_user.info(f"Тип документации: {self.documentation_type}")
    log_user.info("------")

NornickelTender.display = display

# %%
#@title Объявления класса NornickelSite

class NornickelSite:
    URL = 'https://www.nornickel.ru/api/local-tenders/?q=&dateFrom=&dateTo=&page='

# %%
#@title Метод загрузки тендеров NornickelSite и создания экземпляра NornikelTender
def download_tenders(self, load_quantity=0, page_number=None):
    # Устанавливаем заголовки для HTTP запроса
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Accept-Language': 'ru'
    }
    doc_deb.info(f"download_tenders: load_quantity: {load_quantity}")  # Выводим количество тендеров для загрузки

    all_tenders = {}  # Инициализируем словарь для хранения всех тендеров
    count = 0  # Счетчик для ограничения количества загружаемых тендеров
    break_flag = False
    # Если указан номер страницы, загружаем тендеры только с этой страницы
    if page_number:
        url = f"{self.URL}{page_number}"  # Формируем URL
        response = requests.get(url, headers=headers)  # Отправляем HTTP запрос
        if response.status_code == 200:  # Проверяем статус ответа
            data = json.loads(response.text)  # Преобразуем JSON ответ в Python объект
            tenders_data = data.get('items', [])  # Извлекаем список тендеров
            for item in tenders_data:  # Итерируемся по списку тендеров
                count += 1  # Увеличиваем счетчик
                if count <= load_quantity or load_quantity == 0:  # Проверяем, не превышено ли максимальное количество
                    tender = NornickelTender(item)  # Создаем объект тендера
                    all_tenders[tender.id] = tender  # Добавляем тендер в словарь
                else:
                    break
    else:
        url = f"{self.URL}1"  # Формируем URL для первой страницы
        response = requests.get(url, headers=headers)  # Отправляем HTTP запрос
        total_pages = 1  # Значение количества страниц по умолчанию

        if response.status_code == 200:  # Проверяем статус ответа
            data = json.loads(response.text)  # Преобразуем JSON ответ в Python объект
            total_pages = data.get('nav', {}).get('total', 1)  # Получаем общее количество страниц
        doc_deb.info(f"total_pages = {total_pages}")
        for page in range(1, total_pages + 1):  # Итерируемся по всем страницам
            doc_deb.info(f"page = {page}")

            url = f"{self.URL}{page}"  # Формируем URL
            response = requests.get(url, headers=headers)  # Отправляем HTTP запрос
            if response.status_code == 200:  # Проверяем статус ответа
                data = json.loads(response.text)  # Преобразуем JSON ответ в Python объект
                tenders_data = data.get('items', [])  # Извлекаем список тендеров
                doc_deb.debug(f"tenders_data = {tenders_data}")
                for item in tenders_data:  # Итерируемся по списку тендеров
                    count += 1  # Увеличиваем счетчик
                    # print(f"count = {count}, load_quantity = {load_quantity}")
                    if count <= load_quantity or load_quantity == 0:  # Проверяем, не превышено ли максимальное количество
                        # print("Выгрузка тендера")  # Выводим сообщение о выгрузке
                        name = item.get('name', 'Н/Д')  # Извлекаем имя тендера
                        active_to_unix = item.get('activeTo', None)  # Извлекаем дату окончания
                        active_to = datetime.utcfromtimestamp(int(active_to_unix)).strftime('%d.%m.%Y') if active_to_unix else 'Н/Д'  # Преобразуем дату
                        tender = NornickelTender(item)  # Создаем объект тендера
                        all_tenders[(name, active_to)] = tender  # Добавляем тендер в словарь с составным ключом
                    else:
                        break_flag = True
                        break
            if break_flag:
                break

    doc_deb.info(f"Количество тендеров: {len(all_tenders)}")  # Выводим общее количество загруженных тендеров
    return all_tenders  # Возвращаем словарь с тендерами

NornickelSite.download_tenders = download_tenders  # Добавляем метод в класс

# %%
#@title Метод класса преобразования в CRMTender

@classmethod
def convert_to_crmtender(self, nornickel_tenders):
    crm_tenders = {}
    if nornickel_tenders:
        for tender_name_and_date, nornickel_tender in nornickel_tenders.items():
            # Записываем в словарь key - tender_id, value - CRMTender
            crm_tenders[nornickel_tender.id] = CRMTender(nornickel_tender)
        return crm_tenders

NornickelTender.convert_to_crmtender = convert_to_crmtender

# %% [markdown]
# ## 2 Методы работы с файлами класса PurchaseFiles

# %%
#@title Загрузка файла по ссылке
def download_and_save_file(self, url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        folder_path = self.folders["URL"]
        os.makedirs(folder_path, exist_ok=True)
        filename = os.path.join(folder_path, f"{os.path.basename(url)}")

        with open(filename, "wb") as file:
            file.write(response.content)

        self.files.append(filename)
        doc_deb.info(f"Файл успешно загружен и сохранен как {filename}.")
    else:
        error_message = f"Ошибка при загрузке файла. Код ответа: {response.status_code}, Описание: {response.reason}"
        doc_deb.warning(error_message)
        raise RuntimeError(error_message)

# Добавляем метод в класс
PurchaseFiles.download_and_save_file = download_and_save_file

def download_files(self):
    self.files = []
    for url in self.files_urls:
        try:
            self.download_and_save_file(url)
        except RuntimeError as e:
            doc_deb.warning(f"Не удалось загрузить файл по URL {url}. Ошибка: {e}")

# Добавляем метод в класс
PurchaseFiles.download_files = download_files

# %%
#@title Методы распаковки файлов из папки URL в папку UnPack

# Обработка загруженных файлов
def process_files(self):  # Определение метода process_files в классе
    self.unpackfiles = []  # Очистка или инициализация списка unpackfiles

    folder_path = self.folders["UnPackTemp"]  # Получение пути к временной папке для разархивации
    os.makedirs(folder_path, exist_ok=True)  # Создание этой папки, если она не существует

    # Шаг 1: Итерация по файлам в self.files для разархивации
    for filename in self.files:
        if filename.endswith(".zip"):  # Проверка на то, является ли файл архивом .zip
            with zipfile.ZipFile(filename, 'r') as zip_ref:  # Открытие ZIP-архива
                zip_ref.extractall(folder_path)  # Разархивация всех файлов во временную папку
            doc_deb.info(f"Архив {filename} разархивирован в папку {folder_path}.")  # Вывод сообщения о успешной разархивации
        else:
            new_path = os.path.join(folder_path, os.path.basename(filename))  # Путь для перемещения файла
            os.rename(filename, new_path)  # Перемещение файла
            doc_deb.info(f"Файл {filename} перемещен в папку {folder_path}.")  # Вывод сообщения о перемещении файла

    # Шаг 2: Рекурсивно обрабатываем вложенные архивы
    self._process_nested_archives(folder_path)  # Обработка вложенных архивов

    # Шаг 3: Вынимаем файлы из папок и сохраняем в self.unpackfiles
    self._extract_files_from_folder(folder_path)  # Вынимаем файлы из папки и добавляем в self.unpackfiles

    os.system(f"rm -rf {folder_path}")  # Удаление временной папки и её содержимого с помощью команды shell
    if self.unpackfiles == []:  # Проверка на наличие разархивированных файлов
        doc_deb.warning(f"Загруженных архивов .zip для тендера ID={self.id} не найдено.")  # Вывод сообщения, если не найдено архивов

def _process_nested_archives(self, folder_path):
    # Получаем список файлов и папок в текущей директории
    doc_deb.debug(f"folder_path: {folder_path}")
    contents = os.listdir(folder_path)
    for item in contents:
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):  # Проверяем, является ли элемент папкой
            # Рекурсивно обрабатываем вложенные папки
            self._process_nested_archives(item_path)
        elif item.endswith(".zip"):  # Проверяем, является ли элемент архивом .zip
            # Создаем путь для временной папки для разархивации
            nested_folder_path = os.path.join(folder_path, f"temp_unzipped_{item[:-4]}")
            os.makedirs(nested_folder_path, exist_ok=True)
            doc_deb.debug(f"nested_folder_path:{nested_folder_path}")

            # Создаем путь для папки UnZIP внутри временной папки
            unzipped_folder_path = os.path.join(nested_folder_path, "tempUnPack")
            os.makedirs(unzipped_folder_path, exist_ok=True)

            # Разархивируем вложенный архив в папку UnZIP
            with zipfile.ZipFile(item_path, 'r') as zip_ref:
                zip_ref.extractall(unzipped_folder_path)
            doc_deb.info(f"Вложенный архив {item} разархивирован в папку {unzipped_folder_path}.")

            # Рекурсивно обрабатываем вложенные архивы
            self._process_nested_archives(unzipped_folder_path)


def _extract_files_from_folder(self, folder_path):
    doc_deb.debug(f"folder_path: {folder_path}")
    # Получаем список файлов и папок в указанной директории
    contents = os.listdir(folder_path)

    # Итерируемся по элементам содержимого директории, начиная с 1
    for i, item in enumerate(contents, 1):
        item_path = os.path.join(folder_path, item)  # Получаем полный путь к текущему элементу

        if os.path.isfile(item_path):  # Проверяем, является ли элемент файлом
            filename, file_extension = os.path.splitext(item)  # Разделяем имя файла и его расширение
            file_name = f"{i}. {filename}{file_extension}"  # Формируем новое имя файла с номером

            # Добавляем имя файла в список self.unpackfiles
            self.unpackfiles.append(os.path.basename(item_path))

            doc_deb.info(f"Файл {file_name} добавлен в self.unpackfiles.")

        elif os.path.isdir(item_path):  # Проверяем, является ли элемент папкой
            # Рекурсивно вызываем эту же функцию для обработки вложенных папок
            self._extract_files_from_folder(item_path)

            unzipped_folder_path = self.folders["UnPack"]  # Получаем путь к папке UnPack

            if os.path.exists(unzipped_folder_path) and os.path.isdir(unzipped_folder_path):
                # Удаляем папку со старым содержимым, если она существует
                shutil.rmtree(unzipped_folder_path)
                doc_deb.info(f"Папка со старым содержимым удалена: {unzipped_folder_path}")

            # Создаем новую папку UnPack для загрузки файлов
            os.makedirs(unzipped_folder_path, exist_ok=True)

            # Переносим файлы из текущей папки в папку UnPack с новыми именами
            for j, file_name in enumerate(os.listdir(item_path), 1):
                file_path = os.path.join(item_path, file_name)
                new_file_name = f"{j}. {file_name}"
                new_file_path = os.path.join(unzipped_folder_path, new_file_name)
                shutil.move(file_path, new_file_path)
                doc_deb.info(f"Файл {file_name} переименован в {new_file_name} и перемещен в папку UnPack.")

            # Удаляем текущую папку
            os.rmdir(item_path)



# Метод для вывода списка загруженных файлов
def print_files(self):
    if self.files:  # Проверяем, не пуст ли список
        log_user.info(f"Список загруженных файлов:")
        for file in self.files:  # Итерируемся по списку файлов
            log_user.info(file)
    else:
        log_user.warning("Загруженных файлов не найдено.")

# Метод для вывода списка разархивированных файлов
def print_unpackfiles(self):
    if self.unpackfiles:  # проверка, что список не пуст
        log_user.info("Список разархивированных файлов:")
        for file_path in self.unpackfiles:
            log_user.info(f"{file_path}")
    else:
        log_user.warning("Разархивированных файлов не найдено.")

PurchaseFiles.process_files = process_files
PurchaseFiles._process_nested_archives = _process_nested_archives
PurchaseFiles._extract_files_from_folder = _extract_files_from_folder
PurchaseFiles.print_files = print_files
PurchaseFiles.print_unpackfiles = print_unpackfiles

# %%
#@title Методы распаковки файлов из папки URL в папку UnPack НОВОЕ

# Обработка загруженных файлов
def process_files(self):
    self.unpackfiles = []  # Очистка или инициализация списка unpackfiles
    url_path = self.folders["URL"]

    # Создаем папку UnPackTemp
    un_pack_temp_path = self.folders["UnPackTemp"]
    os.makedirs(un_pack_temp_path, exist_ok=True)

    # Создаем папку UnPack
    un_pack_path = self.folders["UnPack"]
    os.makedirs(un_pack_path, exist_ok=True)

    # Запускаем обработку папки URL
    self._process_folder(url_path)

    # Запускаем обработку папки UnPackTemp
    self._process_folder(un_pack_temp_path)

def _process_folder(self, folder_path):
    i = 0
    doc_deb.debug(f"folder_path: {folder_path}")
    while True:
        contents = os.listdir(folder_path)
        i += 1
        doc_deb.debug(f"цикл {i}")

        if not contents or i > 5:
            os.rmdir(folder_path)  # Удаляем пустую папку
            break

        for item in contents:
            item_path = os.path.join(folder_path, item)

            if os.path.isfile(item_path):  # Если элемент - файл
                if item.endswith(".zip"):  # Проверяем расширение файла
                    with zipfile.ZipFile(item_path, 'r') as zip_ref:
                        zip_ref.extractall(self.folders["UnPackTemp"])
                    doc_deb.info(f"Архив {item} разархивирован в папку {self.folders['UnPackTemp']}.")

                    # Удаляем архив, так как он уже разархивирован
                    os.remove(item_path)
                elif item.endswith(".rar"):  # Проверяем расширение файла
                    with rarfile.RarFile(item_path, 'r') as rar_ref:
                        rar_ref.extractall(self.folders["UnPackTemp"])
                    doc_deb.info(f"Архив {item} разархивирован в папку {self.folders['UnPackTemp']}.")

                    # Удаляем архив, так как он уже разархивирован
                    os.remove(item_path)
                elif item.endswith(".7z"):  # Проверяем расширение файла
                    with py7zr.SevenZipFile(item_path, 'r') as sevenzip_ref:
                        sevenzip_ref.extractall(self.folders["UnPackTemp"])
                    doc_deb.info(f"Архив {item} разархивирован в папку {self.folders['UnPackTemp']}.")

                    # Удаляем архив, так как он уже разархивирован
                    os.remove(item_path)
                else:
                    new_file_path = os.path.join(self.folders["UnPack"], item)
                    shutil.move(item_path, new_file_path)
                    doc_deb.info(f"Файл {item} перемещен в UnPack.")
            elif os.path.isdir(item_path):  # Если элемент - папка
                # Запускаем рекурсивную обработку папки
                self._process_folder(item_path)

PurchaseFiles.process_files = process_files
PurchaseFiles._process_folder = _process_folder

# %%
#@title Метод поиска файлов в папке UnPack и создание словаря Документов

# Перебор файлов в папке UnPack и запуск read_file_content
def create_documents(self):
    unpack_folder = self.folders.get("UnPack", None)  # Получаем путь к папке UnPack из словаря self.folders
    temp_folder = self.folders["Temp"]  # Формируем путь к папке Temp
    documents = {}
    if unpack_folder:
        # Создаем временную папку Temp, если она не существует
        if temp_folder:
            os.makedirs(temp_folder, exist_ok=True)  # exist_ok=True не вызовет ошибку, если папка уже существует

            # Проходим по всем файлам в папке UnPack и ее подпапках
            for root, _, files in os.walk(unpack_folder):  # os.walk генерирует имена файлов в дереве каталогов
                for file_name in files:  # Перебираем все файлы
                    file_path = os.path.join(root, file_name)  # Получаем полный путь к файлу
                    doc_deb.info(f">> Путь файла:", file_path)  # Выводим информацию о файле

                    document = Document(self.id, file_name, file_path)

                    # Проверяем, есть ли уже словарь для текущего id
                    if self.id in documents:
                        documents[self.id][file_name] = document
                    else:
                        documents[self.id] = {file_name: document}

                    doc_deb.info("Создан документ ")  # Выводим сообщение, если спецификация найдена

            # Удаляем временную папку и ее содержимое
            os.system(f"rm -rf {temp_folder}")  # Удаляем папку и все ее содержимое
            return documents  # Возвращаем словарь с экземплярами класса Document, сгруппированными по id и именам файлов
        else:
            doc_deb.warning(f"Не задан путь для папки Temp.")
    else:
        doc_deb.warning(f"Отсутствуют файлы в каталоге UnPack.")  # Сообщение, если папка UnPack пуста или не существует

PurchaseFiles.create_documents = create_documents

# %% [markdown]
# ## 3.1 Методы чтения контента класса Document

# %%
#@title Метод определеня расширения файла и запуска метода чтения контента
def read_file_content(self, view_level):
    self.view_level = view_level
    file_path = self.file_path

    temp_folder = self.folders["Temp"]  # Формируем путь к папке Temp
    # Создаем временную папку Temp, если она не существует
    if temp_folder:
        os.makedirs(temp_folder, exist_ok=True)  # exist_ok=True не вызовет ошибку, если папка уже существует

    if isinstance(file_path, (str, bytes, os.PathLike)):
        content = None
        file_extension = os.path.splitext(str(file_path))[1].lower()
        if file_extension == ".docx":
            content = self.read_docx_content()
        elif file_extension == ".doc":
            content = self.read_docx_content()
            pass
        elif file_extension == ".pdf":
            # content = self.recognize_text_from_pdf(file_path)
            pass
        elif file_extension == ".xls":
            # Добавьте вызов метода для чтения XLS
            pass
        else:
            doc_deb.warning(f"Неизвестное расширение файла: {file_extension}. Пропускаю.")
            return None

        # Удаляем временную папку и ее содержимое
        os.system(f"rm -rf {temp_folder}")  # Удаляем папку и все ее содержимое

        if content:
            self.content = content.strip()
            # print(self.content)
            return True

#            is_spec = self.is_specification(content)
#            is_spec_value, error_message = is_spec  # распаковка кортежа
#             print(f"is_cpec: {is_spec}")
#            if is_spec_value is True:
#                self.specification_file_path.append(file_path)
#                self.specification.append(content)
#
#                print(f"СПЕЦИФИКАЦИЯ: {file_path}")
#            elif is_spec_value is False:
#                print(f"Файл не является Спецификацией: {file_path}")
#                return None  # или можете использовать `return False` для большей ясности
#            else:
#                print(f"Ошибка: {error_message or 'Неизвестная ошибка'}")
#                return None
        else:
            return None
    else:
        doc_deb.warning(f"Некорректный путь к файлу: {file_path}. Пропускаю.")
        return None

Document.read_file_content = read_file_content

# %%
#@title Методы преобразования .docx (библиотека docx)

# Чтение файлов с расширением .docx и пропуск остальных файлов.
def read_docx_content(self):
      file_path = self.file_path
      view_level = self.view_level
      content = ""

      if view_level == "Поверхностный":
          txt_file_path = self.convert_docx_to_text()
          content = self.read_txt_content(txt_file_path, max_lines=50)
      elif view_level == "Стандартный":
          txt_file_path = self.convert_docx_to_text()
          content = self.read_txt_content(txt_file_path)
      elif view_level == "Детальный":
          pdf_file_path = self.convert_doc_to_pdf()
          content = self.recognize_text_from_pdf(pdf_file_path)

      return content.strip()

def convert_docx_to_text(self):
    docx_file_path = self.file_path
    file_name = os.path.basename(docx_file_path)  # Получаем имя файла из полного пути

    # Используем значение из одноуровневого словаря self.folders для получения пути к папке Temp
    temp_folder = self.folders["Temp"]

    file_path_temp = os.path.join(temp_folder, file_name + ".txt")  # Формируем путь для временного txt файла в папке Temp

    # Удаляем часть, связанную с расширением файла (.docx), и добавляем ".txt"
    file_path_original = os.path.splitext(docx_file_path)[0] + ".txt"

    subprocess.call(["unoconv", "-f", "txt", docx_file_path])  # Конвертируем файл из docx в txt с помощью unoconv

    os.rename(file_path_original, file_path_temp)  # Переименовываем и перемещаем созданный txt файл в папку Temp

    return file_path_temp  # Возвращаем путь к временному txt файлу


def read_txt_content(self, txt_file_path, max_lines=None):
    content = ""
    with open(txt_file_path, "r", encoding="utf-8") as txt_file:
        if max_lines is None:
            content = txt_file.read()
        else:
            for line_num, line in enumerate(txt_file):
                if line_num >= max_lines:
                    break
                content += line
    return content

Document.read_docx_content = read_docx_content
Document.convert_docx_to_text = convert_docx_to_text
Document.read_txt_content = read_txt_content

# %%
#@title Методы чтения .doc

def read_doc_content(self):
    doc_file_path = self.file_path
    # Преобразование файла в txt
    try:
        txt_file_path = os.path.splitext(doc_file_path)[0] + ".txt"
        subprocess.call(["unoconv", "--format=txt", "--output", txt_file_path, doc_file_path])
    except Exception as e:
        doc_deb.warning(f"Ошибка при конвертации файла {doc_file_path}: {e}")
        return None

    # Чтение файла txt
    try:
        with open(txt_file_path, "r", encoding="utf-8") as file:
            content = file.read()
        return content
    except Exception as e:
        doc_deb.warning(f"Ошибка при чтении файла {txt_file_path}: {e}")
        return None

    # Преобразование в pdf - временно отключено
    #pdf_file_path = self.convert_doc_to_pdf(file_path)
    #content = self.recognize_text_from_pdf(pdf_file_path)

    return content

Document.read_doc_content = read_doc_content

# %%
#@title Метод преобразования файла в PDF (библиотека pdfminer.six)

import subprocess

def convert_doc_to_pdf(self):
    doc_file_path = self.file_path
    file_name = os.path.basename(doc_file_path)  # Получаем имя файла из пути
    temp_folder_path = self.folders["Temp"]  # Получаем путь к папке Temp из одноуровневого словаря self.folders
    file_path_temp = os.path.join(temp_folder_path, file_name + ".pdf")  # Формируем путь для временного pdf файла в папке Temp
    file_path_original = os.path.splitext(doc_file_path)[0] + ".pdf"  # Формируем путь для оригинального pdf файла (без временной папки)

    subprocess.call(["unoconv", "-f", "pdf", doc_file_path])  # Вызываем unoconv для конвертации doc в pdf

    os.rename(file_path_original, file_path_temp)  # Перемещаем созданный pdf файл в папку Temp

    return file_path_temp  # Возвращаем путь к временному pdf файлу

Document.convert_doc_to_pdf = convert_doc_to_pdf

# %%
#@title Метод распознавания PDF (библиотека pdf2image)
if SCAN_MODUL:
    import pytesseract
    from pdf2image import convert_from_path

# Укажите путь к исполняемому файлу Tesseract (на Windows это может быть 'tesseract.exe')
# pytesseract.pytesseract.tesseract_cmd = r'/path/to/tesseract'

def recognize_text_from_pdf(self, pdf_file_path):
    images = convert_from_path(pdf_file_path)
    recognized_text = []

    custom_config = r'--oem 3 --psm 6 -l eng+rus'

    for image in images:
        text = pytesseract.image_to_string(image, config=custom_config)
        recognized_text.append(text)

    return '\n'.join(recognized_text)  # Объединяем строки в одну

Document.recognize_text_from_pdf = recognize_text_from_pdf

# %%
#@title Разделение контента на части
def split_content_into_parts(self):
    self.number_of_parts = 0  # Инициализация счетчика частей
    self.content_parts = []
    self.overloaded = False  # Инициализация переменной overloaded
    total_characters = len(self.content)  # Получение общего количества символов в исходном тексте
    part_number = 1  # Инициализация номера текущей части
    remaining_characters = total_characters  # Инициализация оставшегося количества символов для обработки
    start_idx = 0  # Инициализация индекса для начала каждой новой части

    while remaining_characters > 0 and part_number <= self.part_limit:  # Запуск цикла, продолжающегося до тех пор, пока есть символы для обработки и не превышен лимит частей
        if remaining_characters <= self.token_limit:  # Если осталось меньше символов, чем лимит для части
            part_content = self.content[start_idx:]  # Создание последней части, начиная с текущего индекса
            remaining_characters = 0  # Обнуление оставшихся символов, так как они все будут использованы
        else:
            part_content = self.content[start_idx:start_idx + self.token_limit]  # Выделение символов для текущей части
            remaining_characters -= len(part_content)  # Вычитание количества обработанных символов из оставшихся
            start_idx += self.token_limit  # Перемещение индекса для начала следующей части

        part_characters_count = len(part_content)

        part_number += 1  # Увеличение номера текущей части

        self.content_parts.append(part_content)  # Добавление текущей части в список частей
        self.number_of_parts += 1  # Увеличение счетчика частей

    if part_number > self.part_limit:
        self.overloaded = True  # Если количество частей превышает лимит, устанавливаем overloaded в True

    doc_deb.info(f"Общее количество символов в документе: {total_characters}. Общее количество частей документа: {self.number_of_parts}")  # Вывод общего количества символов в документе

Document.split_content_into_parts = split_content_into_parts

# %% [markdown]
# ## 3.2 Методы и Роли для анализа контента класса Document

# %% [markdown]
# ##### 3.1.3.1 Методы

# %%
#@title Метод проверки является ли контент Документа - спецификацией товаров



def check_specification(self):

    content = self.content

    TOKEN_LIMIT = 4000  # Максимальное количество токенов для одного запроса
    PART_LIMIT = 10  # Максимальное количество частей, которые будут проверены

    system = self.SYSTEM_ROLES["Анализ спецификации"][4]
    topic = content

    # Разбиваем content на части
    parts = [content[i:i + TOKEN_LIMIT] for i in range(0, len(content), TOKEN_LIMIT)]

    # Если частей больше PART_LIMIT, проверяем только первые PART_LIMIT частей
    parts_to_check = parts[:PART_LIMIT]

    for part in parts_to_check:
        try:
            answer = self.answergpt(system, part).strip()  # Удаляем лишние пробелы
        except Exception as e:
            return (None, f"Ошибка при подключении к API: {e}")

        if answer == "Да":
            self.is_specification = True
            return (True, None)
        elif answer == "Нет":
            continue  # Переходим к следующей части
        else:
            self.is_specification = False
            return (None, f"Неожиданный ответ от модели: '{answer}'")

    # Если проверили все доступные части и не нашли спецификацию
    if len(parts) > PART_LIMIT:
        return (None, f"Превышение максимального числа токенов: {len(content)}")
    else:
        return (False, None)

def answergpt(self, system, topic, temp = 1):
    messages = [
      {"role": "system", "content": system},
      {"role": "user", "content": topic}
      ]

    try:
        completion = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=messages,
          temperature=temp
          )
    except Exception as e:
        raise e  # Передаем исключение выше, чтобы обработать его в is_specification
    answer = completion.choices[0].message.content
    # print(f"Запрос в GPT: {topic}")
    # print(f"Ответ GPT: {answer}")
    return answer

Document.check_specification = check_specification
Document.answergpt = answergpt

# %%
#@title Метод определения смысла каждой части и написания аннотации

def parts_abstract(self):
    self.about_parts = []
    if self.content_parts:
        for part in self.content_parts:
            about_part = self._part_abstract(part)
            doc_deb.info(f"Осмысление части:\n{about_part}")
            self.about_parts.append(about_part)
    else:
        doc_deb.warning(f"Части контента для документа {self.name} не заданы")

def _part_abstract(self, part):

    content = part

    system = self.SYSTEM_ROLES["Смысл части текста"][1]
    topic = content

    try:
        answer = self.answergpt(system, part) # Удаляем лишние пробелы
        return answer
    except Exception as e:
        doc_deb.warning(f"Ошибка при подключении к API: {e}")
        return (None, f"Ошибка при подключении к API: {e}")

Document.parts_abstract = parts_abstract
Document._part_abstract = _part_abstract

# %%
#@title Метод определения смысла документа по его частям

def document_meaning(self):

    if self.about_parts:
        formatted_text = ""
        for i, part in enumerate(self.about_parts, start=1):
            formatted_text += f"Часть {i}:\n{part}\n"
        #print(formatted_text)

        system = self.SYSTEM_ROLES["Смысл текста документа"][1]

        about_content = self.answergpt(system, formatted_text).strip()  # Удаляем лишние пробелы

        doc_deb.info(f"Смысл документа {self.name}:\n{about_content}")
        self.about_content = about_content

    else:
        doc_deb.warning(f"Осмысленные описания частей документа {self.name} не заданы")

Document.document_meaning = document_meaning

# %%
#@title Метод задания системной роли

def add_system_role(self, role_name, version, description):
    if role_name not in self.system_roles:
        self.system_roles[role_name] = {}  # Инициализация словаря для данной роли, если ее еще нет
    self.system_roles[role_name][version] = description  # Заполнение описания роли

Document.add_system_role = add_system_role

# %% [markdown]
# ##### 3.1.3.2 Роли

# %%
#@title Роль Анализа содержания спецификации

system1 = """
Ты менеджер по продажам. Ты просматриваешь содержимое файла, который заказчик прислал тебе.
Текст может выглядеть немного разбитым, это могло произойти во время распознавания файла через OCR. Если это так, сначала восстанови его.
Твоя задача определить, является ли данное содержимое - спецификацией товаров, которые заказчик хочет приобрести.
Ключевые признаки спецификации товаров: указан товар и его нзвание
Ты очень ответственно подходишь к ознакомлению. Если ты считаеш это спецификацией, то ты сможешь выделить
список товаров с указанием наименования и количества.
Важно: Твой ответ должен быть либо "Да", либо "Нет". Ты не может отвечать расплывчато, и не добавляй от себя других слов.
Твой ответ не может превышать 3-х символов!!! Не используй знаки прининания.
  """
  # , есть его наименование либо описание, количетсво, ед. измерения, характеристики, и подобное.

system2 = """
Ты ассистент, специализирующийся на анализе документов.
Ты получил файл от заказчика и должен определить, является ли этот файл спецификацией товаров.
Спецификация, как правило, содержит следующую информацию:
наименования товаров, количество, единицы измерения и характеристики. Данные могут быть разрознены.
Твой ответ должен быть крайне ясным и состоять из одного слова: "Да", если это спецификация, и "Нет", если это не так."""

system3 = """
Ты ассистент, специализирующийся на восстановлении отсканированных документов.
Ты получил плохо отсканированный файл от заказчика и должен определить, является ли этот файл спецификацией товаров.
Если да, попытайся восстановить из него спецификацию товаров. Спецификация, как правило, содержит следующую информацию:
наименования товаров, количество, единицы измерения и характеристики.
Если восстановить удалось, твой ответ должен быть крайне ясным и состоять из одного слова: "Да". Если не удалось: "Нет".
Важно: Твой ответ должен быть либо "Да", либо "Нет". Ты не может отвечать расплывчато, и не добавляй от себя других слов.
Твой ответ не может превышать 3-х символов!!! Не используй знаки прининания."""

system4 = """
Ты ассистент, специализирующийся на анализе и восстановлении отсканированных документов.
Тебе предоставлен плохо отсканированный документ от заказчика, и твоя задача определить, является ли этот документ спецификацией товаров.
Спецификация обычно содержит следующие элементы: идентификационные номера (артикулы, SKU и т.д.),
наименования товаров, производителей, количество, единицы измерения, даты, места поставки и другие технические характеристики.
Если документ содержит большую часть этих элементов в любом виде (даже если информация частично неполная или разрозненная из-за плохого качества сканирования),
твой ответ должен быть крайне ясным и состоять из одного слова: 'Да'.
В противном случае, твой ответ должен быть 'Нет'.
Важно: Твой ответ должен быть либо 'Да', либо 'Нет'. Не используй дополнительные слова или знаки препинания. Твой ответ не может превышать 3 символов.
"""
Document.SYSTEM_ROLES["Анализ спецификации"] = {
    1: system1,
    2: system2,
    3: system3,
    4: system4
}

# %%
#@title Роль Смысл части текста

system1 = """
Ты тендерный специалист, осуществляющий работу с тендерной документацией со стороны поставщика.
Наша компания осуществляет поставку товаров.
Ты получил одну из частей документа либо документ целиком,
который загрузил из тендерной документации заказчика с его сайта.
Тебе необходимо осмыслить содержание и придумать название документа.
В ответ ты сообщаешь краткую аннотацию для нашего банка данных, которая включает в себя:
1. Название: <вставь придуманное название>.
2. Содержание: <вставь осмысленное тобою содержание>.
Важно! Ничего не добавляй свыше указанных данных аннотации. Только информацию по двум пунктам.
Важно! Общий объем твоего ответа не должен превышать 100 символов. Иначе он будет обрезан системой.

  """
system2 = """

  """
Document.SYSTEM_ROLES["Смысл части текста"] = {
    1: system1,
    2: system2
}

# %%
#@title Роль Смысл текста документа

system1 = """
Ты тендерный специалист, осуществляющий работу с тендерной документацией со стороны поставщика.
Наша компания осуществляет поставку товаров.
Ты получил несколько или одну часть документа.
После этого ты составил аннотацию к каждой части документа в следующем формате:
1. Название: <придуманное тобой название>.
2. Содержание: <осмысленное тобою содержание>.
В аннотация содержание разных частей одного документа.

Сейчас тебе необходимо проанализировать содержание всех этих частей (либо одно части) и
выдать свое техническое заключение: назвние этого документа и его осмысленное содержание.
Если содержание частей различное, объедини по смыслу в один документ.
Руководствуйся данными полученными в аннотациях и своим опытом в тендерных закупках.

В ответ пришли:
1. Документ: <придуманное тобой название>.
2. Описание: <осмысленное тобою содержание частей документа>.

Важно! Это все части одного документа. Укажи, только информацию по двум пунктам.
Важно! Общий объем твоего ответа не должен превышать 100 символов. Иначе он будет обрезан системой.

  """
system2 = """

  """
Document.SYSTEM_ROLES["Смысл текста документа"] = {
    1: system1,
    2: system2
}

# %% [markdown]
# ## 4 Методы работы с архивом Google Drive

# %%
#@title Методы класса Database

def add_data(self, instance_dict):
    if not instance_dict:
        db_deb.warning("Пустой словарь передан")
        return "Пустой словарь передан"

    first_key = next(iter(instance_dict))
    first_value = instance_dict[first_key]

    if isinstance(first_value, dict):
        # Если первый элемент является вложенным словарем, берем тип одного из его значений
        nested_first_key = next(iter(first_value))
        instance_type = type(first_value[nested_first_key]).__name__
    else:
        instance_type = type(first_value).__name__

    if instance_type == "NornickelTender":
        self.NornickelTender_db.update(instance_dict)  # Обновляем или добавляем
    elif instance_type == "PurchaseFiles":
        self.PurchaseFiles_db.update(instance_dict)  # Обновляем или добавляем
    elif instance_type == "Document":
        self.Document_db.update(instance_dict)  # Обновляем или добавляем
    elif instance_type == "CRMTender":
        self.CRMTender_db.update(instance_dict)  # Обновляем или добавляем

    else:
        raise ValueError(f"Unknown instance type: {instance_type}")  # Выбрасываем исключение

    db_deb.info(f"Данные типа {instance_type} успешно добавлены или обновлены")
    return f"Данные типа {instance_type} успешно добавлены или обновлены"



def save(self, filepath):
    with open(filepath, 'wb') as output_file:
        pickle.dump(self, output_file)

def erase(self):
    self.NornickelTender_db = {}
    self.PurchaseFiles_db = {}
    self.Document_db = {}
    with open(self.file_path, 'wb') as output_file:
        pickle.dump(self, output_file)
    db_deb.info("Данные из Базы данных удалены")

def get_data(self):
    with open(self.file_path, 'rb') as input_file:
        loaded_archive = pickle.load(input_file)
    return loaded_archive



DataBase.add_data = add_data
DataBase.save = save
DataBase.get_data = get_data
DataBase.erase = erase

# %% [markdown]
# ## 5 Обработчики API запросов

# %%
#@title Обработчик API-запроса на загрузку тендеров Норникеля
FUNC_NAME = "nornickel_tenders"
FUNC_DESC = "Загрузка тендеров с сайта Норникеля"
FUNC_RESULT = f"Тендеры с описанием и документами загружены в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Загружаю закупки с сайта Норникель..."

def api_request_nornickel_tenders(self, function_args):

    # Извлекаем аргументы для данной функции
    load_quantity = function_args.get("load_quantity")
    page_number = function_args.get("page_number")
    if load_quantity == None:
        load_quantity = 10 # ВРЕМЕННО ЛИМИТ!!!!!
    if page_number == None:
        page_number = 2 # Искусственное ограничение количества страниц парсинга на период теста.
    api_deb.info(f"load_quantity {load_quantity}, page_number {page_number}")

    # Обработка запроса

    # Создание экземпляра класса NornickelSite
    nornickel_site = NornickelSite()
    downloaded_nornickel_tenders = {}
    nornickel_tenders = {}
    count = 0

    # Загрузка тендеров с конкретной страницы и создание экземпляра NornickelTenders
    downloaded_nornickel_tenders = nornickel_site.download_tenders(load_quantity, page_number)

    # Вывод информации на экран
    for name, tender in downloaded_nornickel_tenders.items():
        count += 1
        nornickel_tenders[(tender.name,tender.active_to)] = tender
        tender.display()

    self.inf_for_user["nornickel_tenders"] = nornickel_tenders

    # Создание экземпляров PurchaseFiles
    all_documents = {} # key: tender_id, item: tender_documents {}
    tenders_id = []

    for tender_id, nornickel_tender in nornickel_tenders.items():
        purchase_files = nornickel_tender.create_purchase_files() # Создаем экземпляр класса PurchaseFiles
        api_deb.info(f"Создан экземпляр PurchaseFiles {purchase_files.id}")

        try:
            # Загрузка файлов PurchaseFiles по ссылке в папку /tender_id/URL
            purchase_files.download_files()  # Запуск метода download_files для каждого объекта PurchaseFiles
            api_deb.info(f"Загрузка файлов для тендера с ID {tender_id} завершена.")  # Опционально: вывод информационного сообщения

            # Распаковка файлов из папки URL в папку UnPack и создание Документов на основе Файлов
            all_documents[tender_id] = {}
            purchase_files.process_files() # Запуск метода process_files для каждого объекта PurchaseFiles
            api_deb.info(f"Распаковка файлов для тендера с ID {tender_id} завершена.")

            # Выгружаем словарь документов по каждой закупке
            tender_documents = purchase_files.create_documents() # key: name, item: Document()
            all_documents[tender_id] = tender_documents

            nornickel_tender.documents = tender_documents

            tenders_id.append(tender_id)

        except RuntimeError as e:
            api_deb.warning(f"Не удалось загрузить файл по URL {url}. Ошибка: {e}")


    self.inf_for_user["documents"] = all_documents

    answer = f"""Успешно. Сотруднику представлена информация о {count} тендерах с сайта Норникель.
    Тендеры c вложенными документами загружены в кэш пользователя '{FUNC_NAME}' под номерами {tenders_id}"""

    system = f"""
        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.
        Кроме того обязательно спроси сотрудника, нужно ли тебе заняться осознанием содержания загруженных
        тендеров. Эти данные сохраняются в кэш пользователя '{FUNC_NAME}'.
        Вероятнее всего он попросит тебя загрузить их в CRM (функция load_to_crm).
        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры."""
    return answer, system

# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "load_quantity": {
                "type": "integer",
                "description": "Количество закупок, которые необходимо загрузить",
            },
            "page_number": {
                "type": "integer",
                "description": "Номер страницы для загрузки данных, при указании параметра 'load_volume'='PAGE'",
            },
        },
    },
}

#---
#Роль при запросе загрузки тендеров
system = """Ты бот, который помагает сотрудникам нашей компании получать доступ к функциям API
    Твоя задача получив запрос пользвателя, вызвать подходящую функцию, тщательно определив значения параметров.
    В случае получения успешного овтета от API - направить пользователю ответ.
    В случае получения неуспешного ответа от API, то попробуй сформировать новый запрос к API, доработав
    входные параметры. Если таких запросов стало более 5, сообщи пользователю о возникающей ошибке от API.
    В случае если данных для формирования запроса не хваратет, направь пользователю зарпос этих данных.
    Важно! Отвечай только преобразовав полученную от API информацию, не добавляй и не дополняй от себя"""
API_DBM.system_roles[FUNC_NAME] = system
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM.api_request_nornickel_tenders = api_request_nornickel_tenders
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_nornickel_tenders
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на фильтрацию значений в кэше пользователя
FUNC_NAME = "data_filter"
FUNC_DESC = "Фильтрация данных в кэше пользователя по заданным параметрам"
FUNC_RESULT = f"Отфильтрованные данные загружены в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Фильтрую данные..."

#API_DBM.func_names.append(FUNC_NAME)
#API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
#API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
#API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на загрузку информации в CRM
FUNC_NAME = "load_to_crm"
FUNC_DESC = "Загрузка данных в CRM из кэша пользователя"
FUNC_RESULT = "Данные из кэша пользователя загружены в CRM"
FUNC_MESSAGE = "Загружаю данные в CRM..."

def api_request_load_to_crm(self, function_args):
    FUNC_NAME = "load_to_crm"
    self.inf_for_user[FUNC_NAME] = []
    # Извлекаем аргументы для данной функции
    cache_name = function_args.get("cache_name") # Тип данных
    api_deb.info(f"cache_name {cache_name}")

    # Обработка запроса
    if cache_name == "nornickel_tenders":
        nornickel_tenders = self.inf_for_user[cache_name]
        crm_tenders = NornickelTender.convert_to_crmtender(nornickel_tenders) # Создаем словарь. key - id, value - CRMTender
        keys = crm_tenders.keys()
        api_deb.debug(f"keys {keys}")
        CRM.add_data(crm_tenders) #
        answer = f"Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:{keys}"
        self.inf_for_user[FUNC_NAME] = crm_tenders

    elif cache_name == "documents": # Необходимо создать обработчик API-запроса create_documents
        CRM.add_data(self.inf_for_user[variable])
        answer = "Успех. Данные успешно загружены в CRM"
        self.inf_for_user[FUNC_NAME] = self.inf_for_user[cache_name]

    else:
        answer = f"Ошибка! Не корректно указаны данные data_type. Вызовите функцию повторно, и укажите значение в соответствии с правилами"

    system = """
        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.
        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры."""
    return answer, system

# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "cache_name": {
                "type": "string",
                "enum": ["nornickel_tenders", "documents"],
                "description": "Имя кэша пользователя",
            },
        },
        "required": ["cache_name"],
    },
}


API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM.api_request_load_to_crm = api_request_load_to_crm
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_load_to_crm
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на формирование поисковой выдачи Google

GOOGLE_API_KEY = "AIzaSyDOWEsO6SQ0o6E2y8waBsJC8fbSQ7DOwC0"
GOOGLE_SEARCH_ENGINE_ID = "807dcef1cb67d4dfe"

FUNC_NAME = "google_search"
FUNC_DESC = "Формирование поисковой выдачи Google"
FUNC_RESULT = f"Результат поисковой выдачи загружен в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Направил запрос в Google..."

def api_request_google_search(self, function_args):

    FUNC_NAME = "google_search"

    self.inf_for_user[FUNC_NAME] = [] # Обнуление дополнительной информации пользователю от системы

    # Извлекаем аргументы для данной функции
    search_query = function_args.get("search_query")

    # print("search_query", search_query)

    # Обработка запроса

    # URL для выполнения запроса
    url = f"https://www.googleapis.com/customsearch/v1?q={search_query}&key={GOOGLE_API_KEY}&cx={GOOGLE_SEARCH_ENGINE_ID}"

    # Выполняем запрос
    response = requests.get(url)
    search_results = response.json()
    search_output = []
    if "items" in search_results:
        #print(search_results)
        total_length = 0  # Переменная для хранения общей длины
        for i, result in enumerate(search_results["items"], start=1):
            title = result["title"]
            link = result["link"]
            snippet = result["snippet"]
            entry = {"i": i, "title": title, "link": link, "snippet": snippet}
            self.inf_for_user[FUNC_NAME].append(entry)
            # Рассчитываем длину добавляемой строки в JSON-формате
            entry_length = len(json.dumps(entry))

            # Проверяем, чтобы общая длина не превышала 5000 символов в json формате
            if total_length + entry_length <= 5000:
                search_output.append(entry)
                total_length += entry_length

            api_deb.info(f"{i}. {title}, Ссылка: {link}, {snippet}")
        length = len(self.inf_for_user[FUNC_NAME])
        answer = f"Сотруднику направлена выгрузка из {length} результатов поисковой выдачи"

    else:
        answer = "Ошибка. Результатов не найдено"

    system = """
        Ты получил ответ от системы. Он содержит несколько первых результатов поисковой выдачи на вопрос сотрудника.
        Составь развернутый ответ сотруднику на основании этой информации.
        Не перечисляй все данные поисковой выдачи. Система уже направила сотруднику результаты поисковой выдачи,
        которые сохранены в переменной google_search.
        Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос"""
    llm_llm.info(f"answer: {answer}")
    return answer, system

# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "search_query": {
                "type": "string",
                "description": "Поисковый запрос в Google для наиболее релевантного ответа",
            },
        },
        "required": ["search_query"],
    },
}


API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM.api_request_google_search = api_request_google_search
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_google_search
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на анализ информации в интернете

FUNC_NAME = "internet_analysis"
FUNC_DESC = "Анализ информации в интернете (до 10 мин)"
FUNC_RESULT = f"Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Анализ данных в интернете..."

def api_request_internet_analysis (self, function_args):
    FUNC_NAME = "internet_analysis"

    self.inf_for_user[FUNC_NAME] = [] # Обнуление дополнительной информации пользователю от системы
    # Извлекаем аргументы для данной функции
    search_query = function_args.get("search_query")

    # print("search_query", search_query)

    # Обработка запроса
    if not self.inf_for_user["google_search"]:
        # 1.Формирование запроса в интернет
        self.api_request_google_search(function_args)

# 2.Удаление нерелевантной информации из поисковой выдачи
    temp_api = API_DBM(["remove_nonrelevant_results"]) #Создание временного объекта API
    # Ограничиваем набор известных GPT функций только одной функцией

    temp_api.inf_for_user["google_search"] = self.inf_for_user["google_search"] #Передаем данные поисковой системы
    system = API_DBM.system_roles["remove_nonrelevant_results"] #Задаем роль чату GPT в запросе
    system = f"{system}\n Поисковый запрос сотрудника: {search_query}" #Добавляем в роль информацию о поисковом запросе сотрудника

    search_results = self.inf_for_user[FUNC_NAME]

    # Подготовка запроса на исключение нерелевантных запросов
    user = []
    with_api = True
    api_deb.debug(f"search_results: {search_results}")
    total_length = 0  # Инициализация переменной
    answer = ""

    for i, result in enumerate(search_results, start=1):
            title = result["title"]
            link = result["link"]
            snippet = result["snippet"]
            entry = {"i": i, "title": title, "link": link, "snippet": snippet}

            # Рассчитываем длину добавляемой строки в JSON-формате
            entry_length = len(json.dumps(entry))

            # Проверяем, чтобы общая длина не превышала 5000 символов в json формате
            if total_length + entry_length <= 5000:
                user.append(entry) # Добавляем поисковую строку к сообщению User для GPT
                total_length += entry_length
            else:
                # Как только превысило порог, запускаем метод исключения и обнуляем лимиты.
                answer = f"{answer}. {temp_api.get_response(user, with_api, False, system)}" # Запускаем исключение нерелевантных ответов
                total_length = 0
                user = []

    answer = f"{answer}. {temp_api.get_response(user, with_api, False, system)}" # Запускаем исключение нерелевантных ответов оставшихся позиций
    self.inf_for_user[FUNC_NAME] = temp_api.inf_for_user["remove_nonrelevant_results"]

    system = f"""
        Ты получил ответ от системы. Он содержит наиболее релевантные результаты поисковой выдачи Google на вопрос сотрудника.
        На основании ответов Google составь развернутый ответ сотруднику, раскрывающий суть найденной в интернете информации.
        Не перечисляй все данные поисковой выдачи. Система уже направила сотруднику результаты, которые также сохранены
        в кэш пользователя '{FUNC_NAME}'.
        Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос"""

    llm_llm.info(f"answer: {answer}")
    return answer, system

#---
# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "search_query": {
                "type": "string",
                "description": "Поисковый запрос в Google для наиболее релевантного ответа",
            },
            "depth": {
                "type": "string",
                "enum": ["Поверхностный", "Стандартный", "Глубокий"],
                "description": "Глубина анализа. Поверхностный - 1 мин, Глубокий - до 10 мин",
            },
        },
        "required": ["search_query", "depth"],
    },
}




API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM.api_request_internet_analysis = api_request_internet_analysis
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_internet_analysis
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на исключение нерелевантных ответов из поисковой выдачи Google
from urllib.parse import urlparse

url = 'https://www.tripadvisor.ru/Attractions-g298525-Activities-c61-Krasnoyarsk_Krasnoyarsk_Krai_Siberian_District.html'
parsed_url = urlparse(url)
domain = parsed_url.netloc

FUNC_NAME = "remove_nonrelevant_results"
FUNC_DESC = "Исключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели"
FUNC_RESULT = f"""Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.
Обновленная поисковая выдача помещена в кэш пользвателя '{FUNC_NAME}'"""
FUNC_MESSAGE = "Исключение нерелевантных запросов..."
def _api_request_remove_nonrelevant_results (self, function_args):
    FUNC_NAME = "remove_nonrelevant_results"

    search_results = self.inf_for_user["google_search"]
    self.inf_for_user[FUNC_NAME] = []

    # Извлекаем аргументы для данной функции
    remove_numbers = function_args.get("remove_numbers")

    # print("remove_numbers", remove_numbers)

    results = []
    answer = "Оставлены следующие релевантные ответы поисковой выдачи:"
    # Обработка запроса
    for result in search_results:
        if result["i"] not in remove_numbers:
            i = result["i"]
            title = result["title"]
            parsed_url = urlparse(result["link"])
            link = parsed_url.netloc # Задаем краткий домена https://www.domain.ru/
            snippet = result["snippet"]
            entry = {"i": i, "title": title, "link": link, "snippet": snippet[:50]}
            results.append(result)
            answer = f"{answer}, "

    self.inf_for_user[FUNC_NAME].append(results)

    if results and len(results) != len(search_results):
        answer = f"Успех. Нерелевантные номера удалены. Оставлены следующие релевантные ответы поисковой выдачи: {answer}"
    elif results and len(results) == len(search_results):
        answer = f"Ошибка. Аргументы функции распознаны не верно"
    else:
        answer = f"Успех. Нерелевантные номера удалены. В поисковой выдаче не осталось номеров"

    system = API_DBM.system_roles["after_api_remove_nonrelevant_results"]

    llm_llm.info(f"answer: {answer}")
    return answer, system

# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "remove_numbers": {
                "type": "array",
                "items": {
                    "type": "integer"
                },
                "description": "Исключаемые номера ответов",
            },
        },
    },
}


API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM._api_request_remove_nonrelevant_results = _api_request_remove_nonrelevant_results
API_DBM.class_functions[FUNC_NAME] = API_DBM._api_request_remove_nonrelevant_results
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на вызов цепочки действий
FUNC_NAME = "chain_actions"
FUNC_DESC = "Описание цепочки подзадач"
FUNC_RESULT = f"Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Определяю план действий..."

def api_request_chain_actions(self, function_args):
    FUNC_NAME = "chain_actions"

    self.inf_for_user[FUNC_NAME] = [] # Обнуление дополнительной информации пользователю от системы
    # Извлекаем аргументы для данной функции
    subtasks = []
    top_task = function_args.get("top_task") # Исходная задача пользователя
    subtasks = function_args.get("subtasks") # Список подзадач функций - список словарей. В этом списке каждый словарь
    # будет содержать поля "name" и "question", как это определено в описании API
    api_deb.info(f"subtasks: {subtasks}")

    self.inf_for_user = {}
    with_api = True
    answer = {}
    all_answers = ""
    system = f"""Сформируй запрос к API по задаче пользователя.
    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.
    Цель пользователя: {self.user_goal}
    """
    for subtask in subtasks:
        # Для каждой функции будем создавать свой экземпляр класса API DBM и ставить для каждого решение отдельного вопроса
        # Это делается именно так, потому что мы не знаем параметры вызываемой функции. Знаем лишь имя функции и задачу которую нужно решить.
        function_name = subtask["name"]
        api_deb.debug(f"function_name: {function_name}")

        action = subtask['action']
        user = f"{action}"
        aviable = True
        if function_name not in list(API_DBM.class_api_rules.keys()): # Имя функции определено не корректно
            api_deb.info(f"Функция запуска не корректна: {function_name}. Запуск обрабтки обращения с расширенными возможностями")
            user = f"{user}\n Похожее название функции:{function_name}" # Подсказываем имя функции.

            # Значит разрешаем все функции, кроме chain_actions.
            function_name = "chain_actions"
            aviable = False
        else:
            api_deb.info(f"Функция запуска определена корректно: {function_name}")

        func_api_dbm = API_DBM([function_name], aviable, level=self.level+1) # Создаем экземпляр класса API DBM
        func_api_dbm.inf_for_user = self.inf_for_user # Загружаем результаты выполнения всех предыдущих запросов
        func_api_dbm.user_goal = self.user_goal # Загружаем конечную цель
        llm_llm.debug(f"Запрос в LLM {self.level+1} уровня: {user}. system: {system}")
        answer = func_api_dbm.get_response(user, with_api, False, system) # Запускаем запрос к чату GPT на решение конкретного вопроса.
        llm_llm.debug(f"Ответ LLM: {answer}")
        all_answers = f"{all_answers}. Результат выполнения '{function_name}': {answer}"
        self.inf_for_user[function_name] = func_api_dbm.inf_for_user[function_name] # Сохраняем в текущем экземпляре результаты (пользовательские данные)

    self.inf_for_user[FUNC_NAME] = self.inf_for_user[function_name] # Записываем итоговый результат
    llm_llm.debug(f"all_answers: {all_answers}")

    system = f"""
        Ты получил ответ в виде списка результатов по каждой выполненной функции. Данные по каждой функции выведены сотруднику.
        Твоя задача сформировать итоговое заключение по задаче пользователя. И попросить его дать обратную связь, правильно ли
        была подобрана стратегия. Всех необходимые данные находятся в кэше пользователя.
        Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос"""
    llm_llm.info(f"all_answers: {all_answers}")
    return all_answers, system

# Правило, объясняющее GPT как формировать API запроса
api_descr1 = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "top_task": {
                "type": "string",
                "description": "Исходная (верхнеуровневая) задача пользователя",
            },
            "subtasks": {
                "type": "array",
                "items": {
                    "type": "object",
                    "properties": {
                        "action": {
                            "type": "string",
                            "description": "Описание подзадачи на человеческом языке с вниманием к деталям"
                        },
                        "name": {
                            "type": "string",
                            "enum": list(API_DBM.class_functions.keys()),  # Список возможных значений из переменной API_DBM.func_names
                            "description": "Кодовое имя соответствующей возможности"
                        },
                    },
                    "required": ["name", "question"]
                },
                "description": "Список подзадач, в порядке их выполнения",
            },
        },
        "required": ["top_task"],
    },
}
# ВЕРСИЯ 2
api_descr2 = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "top_task": {
                "type": "string",
                "description": "Исходный (верхнеуровневый) запрос сотрудника",
            },
            "actions": {
                "type": "array",
                "items": {
                    "type": "string",
                    "description": "Текстовые описания подзадач, в порядке их выполнения"
                }
            },
        },
        "required": ["top_task", "actions"],  # Обновлено
    },
}


API_DBM.class_api_rules[FUNC_NAME] = api_descr1
API_DBM.api_request_chain_actions = api_request_chain_actions
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_chain_actions
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %%
#@title Обработчик API-запроса на осознание документов тендеров CRM
FUNC_NAME = "content_comprehension"
FUNC_DESC = "Осознание содержания элементов CRM"
FUNC_RESULT = f"Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя '{FUNC_NAME}'"
FUNC_MESSAGE = "Осознаю содержание документа ..."

def api_request_content_comprehension(self, function_args):

    # Извлекаем аргументы для данной функции
    element_type = function_args.get("element_type")
    crm_ids = function_args.get("crm_ids")
    api_deb.info(f"element_type {element_type}, crm_ids {crm_ids}")

    # Обработка запроса
    CRM.get_data() # Подгружаем данные из файла архива
    crm_tenders = {}

    if element_type == "crm_tenders":
        for crm_id in crm_ids:
            crm_tender = CRM.CRMTender_db[crm_id]
            documents = crm_tender.documents

            if documents:
                for doc_name, document in documents.items():

                  # Вызов метода read_file_content для текущего объекта Document
                  if document.read_file_content(level) == True:
                      api_deb.info(f"Получен контент документа {document.name}")
                      document.split_content_into_parts() # Разделение контента документа на части
                      document.parts_abstract() # Осмысление каждой части документа
                      document.document_meaning() # Осмысление документа целиком
                      api_deb.info(f"Для тендера {document.tender_id} содержание документа {document.name}: \n{document.about_content}")

                      documents[doc_name] = document
                  else:
                      api_deb.warning(f"Не получен контент документа {document.name}")
                      api_deb.warning(f"Контент: {document.content}")
                crm_tender.documents = documents
                crm_tenders[crm_id] = crm_tender
        CRM.add_data(crm_tenders)
        self.inf_for_user["crm_tenders"] = crm_tenders
        self.inf_for_user[FUNC_NAME] = crm_tenders

        answer = f"""Успешно. Сотруднику представлена информация о содержании документов тендеров CRM crm_ids: {crm_ids}
        Тендеры c осознанными данными обновлены в CRM и загружены в кэш пользователя 'crm_tenders'"""

    system = f"""
        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.
        Кроме того обязательно спроси сотрудника, нужно ли тебе что то сделать с осознанными тендерами.
        Если нужно, мы можешь получить доступ к ним из кэша пользователя'.
        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры."""
    llm_llm.info(f"answer: {answer}")
    return answer, system

# Правило, объясняющее GPT как формировать API запроса
api_descr = {
    "name": FUNC_NAME,
    "description": FUNC_DESC,
    "parameters": {
        "type": "object",
        "properties": {
            "element_type": {
                "type": "string",
                "enum": ["crm_tenders"],
                "description": "Тип данных в CRM",
            },
            "crm_ids": {
                "type": "array",
                "items": {
                    "type": "integer"
                },
                "description": "Список id элементов в базе данных CRM",
            },
        },
        "required": ["element_type", "crm_ids"],
    },
}

#---
#Роль при запросе осознания содержания
system = """Ты аналитик, который помагает сотрудникам нашей компании анализировать данные.
    Твоя задача получив запрос пользвателя, вызвать подходящую функцию, тщательно определив значения параметров.
    В случае получения успешного овтета от API - направить пользователю ответ.
    В случае получения неуспешного ответа от API, то попробуй сформировать новый запрос к API, доработав
    входные параметры. Если таких запросов стало более 5, сообщи пользователю о возникающей ошибке от API.
    В случае если данных для формирования запроса не хваратет, направь пользователю зарпос этих данных.
    Важно! Отвечай только преобразовав полученную от API информацию, не добавляй и не дополняй от себя"""
API_DBM.system_roles[FUNC_NAME] = system
API_DBM.func_names.append(FUNC_NAME)
API_DBM.class_api_rules[FUNC_NAME] = api_descr
API_DBM.api_request_content_comprehension = api_request_content_comprehension
API_DBM.class_functions[FUNC_NAME] = API_DBM.api_request_content_comprehension
API_DBM.func_message[FUNC_NAME] = FUNC_MESSAGE
API_DBM.func_desc[FUNC_NAME] = FUNC_DESC
API_DBM.func_result[FUNC_NAME] = FUNC_RESULT

# %% [markdown]
# ## 5.2 Методы GPT

# %%
#@title Метод отправки запроса и обработки ответа, включающего API-запрос GPT
def _answergpt_with_api(self, message_history):
    # print(f"Запуск answergpt:\n{messages}")
    inf_for_user = []
    messages = message_history
    # Отправка запроса в GPT с поддержкой вызова функций
    api_deb.debug(f"История сообщений в начале запроса: message_history: {message_history}")
    api_deb.debug(f"Объявленная API для LLM: list(self.available_api.values()): {list(self.available_api.values())}")
    response = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo-0613",
        messages = messages,
        functions = list(self.available_api.values()), # Переменная, содержащая объяснение, как формировать запросы API
        function_call = "auto",  # автоматическое определение необходимости вызова API
    )
    # print(f"Ответ GPT:\n{response}")
    # Обработка ответа GPT

    response_message = response["choices"][0]["message"]
    #print("_answergpt_with_api: response_message", response_message)

    # Проверяем, хочет ли GPT вызвать функцию
    if response_message.get("function_call"):
        function_name = response_message["function_call"]["name"] # Получаем имя функции
        function_to_call = API_DBM.class_functions.get(function_name, None) # Пытаемся найти функцию среди доступных

        # Используем json.loads для преобразования строки в JSON объект
        function_args = json.loads(response_message["function_call"]["arguments"]) # Получаем аргуметы вызываемой функции

        #Запускаем обработчик и получаем его ответ
        if function_to_call: # Обработчик найден
            api_deb.info(f"{self.level}. API ОБРАБОТЧИК НАЙДЕН: {function_name}, аргументы: {function_args}\n")
            llm_llm.info(f"{API_DBM.func_message[function_name]}") # Сообщение пользователю
            function_response, system = function_to_call(self, function_args)  # Запуск подобранного обработчика
            llm_llm.info(f"Ответ LLM: {function_response}")
            inf_for_user = self.inf_for_user[function_name] # Получаем данные для пользователя
            messages.append(response_message) #Добавляем в историю переписки запрос функции от GPT
            messages.append({"role": "function", "name": function_name, "content": function_response}) # Добавляем в историю переписки ответ от обработчика API запроса

            if system:
                messages.append({"role": "system", "content": system}) # Если задана новая роль, перед новым запросом добавляем ее в историю переписки.
        else:
            function_response = f"Запрашиваемой функции '{function_name}' не найдено в базе. Попробуйте указать точное имя функции согласно библиотеке"
            llm_llm.warning(function_response)


        #Запускаем рекурсивно еще один запрос к GPT, сохраняя историю переписки, чтобы он подготовил ответ пользователю
        llm_llm.debug(f"Запрос без API в LLM для ответа пользователю: {messages}")
        response_message = self._answergpt(messages)
        api_deb.debug(f"response_message: {response_message}")
        llm_llm.info(f"Ответ LLM пользователю: {response_message.content}")
        #if response_inf_for_user != []:
        #    inf_for_user = response_inf_for_user # Если в рекурсивно запущенном запросе изменилась inf_for_user, то возвращяем измененную переменную

    api_deb.debug(f"История сообщений в конце запроса: message_history: {message_history}")
    return response_message, inf_for_user

API_DBM._answergpt_with_api = _answergpt_with_api

# %%
#@title Метод отправки запроса и обработки ответа, включающего API-запрос GPT НОВЫЙ!!!!
def _answergpt_with_api(self, message_history):
    # print(f"Запуск answergpt:\n{messages}")
    inf_for_user = []
    messages = message_history
    # Отправка запроса в GPT с поддержкой вызова функций
    api_deb.debug(f"История сообщений в начале запроса: messages: {messages}")
    api_deb.debug(f"Объявленная API для LLM: list(self.available_api.values()): {list(self.available_api.values())}")
    response = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo-0613",
        messages = message_history,
        functions = list(self.available_api.values()), # Переменная, содержащая объяснение, как формировать запросы API
        function_call = "auto",  # автоматическое определение необходимости вызова API
    )
    # print(f"Ответ GPT:\n{response}")
    # Обработка ответа GPT

    response_message = response["choices"][0]["message"]
    #print("_answergpt_with_api: response_message", response_message)

    # Проверяем, хочет ли GPT вызвать функцию
    if response_message.get("function_call"):
        function_name = response_message["function_call"]["name"] # Получаем имя функции
        function_to_call = API_DBM.class_functions.get(function_name, None) # Пытаемся найти функцию среди доступных

        # Используем json.loads для преобразования строки в JSON объект
        function_args = json.loads(response_message["function_call"]["arguments"]) # Получаем аргуметы вызываемой функции

        #Запускаем обработчик и получаем его ответ
        if function_to_call: # Обработчик найден
            api_deb.info(f"{self.level}. API ОБРАБОТЧИК НАЙДЕН: {function_name}, аргументы: {function_args}\n")
            log_user.info(f"{API_DBM.func_message[function_name]}")
            function_response, system = function_to_call(self, function_args)  # Запуск подобранного обработчика
            inf_for_user = self.inf_for_user[function_name] # Получаем данные для пользователя
            api_deb.debug(f"История сообщений перед добавлением в message_history: messages: {messages}")
            message_history.append(response_message) #Добавляем в историю переписки запрос функции от GPT
            api_deb.debug(f"История сообщений после добавления в message_history: messages: {messages}")
            message_history.append({"role": "function", "name": function_name, "content": function_response}) # Добавляем в историю переписки ответ от обработчика API запроса

            if system:
                message_history.append({"role": "system", "content": system}) # Если задана новая роль, перед новым запросом добавляем ее в историю переписки.
        else:
            function_response = f"Запрашиваемой функции '{function_name}' не найдено в базе. Попробуйте указать точное имя функции согласно библиотеке"
            llm_llm.warning(function_response)


        #Запускаем рекурсивно еще один запрос к GPT, сохраняя историю переписки, чтобы он подготовил ответ пользователю
        llm_llm.info(f"Запрос без API в LLM для ответа пользователю: {function_response}")
        llm_llm.debug(f"Запрос без API в LLM для ответа пользователю: {message_history}")
        response_message = self._answergpt(message_history)
        llm_llm.info(f"Ответ LLM пользователю: {response_message.content}")
        llm_llm.debug(f"response_message: {response_message}")
        #if response_inf_for_user != []:
        #    inf_for_user = response_inf_for_user # Если в рекурсивно запущенном запросе изменилась inf_for_user, то возвращяем измененную переменную

    api_deb.debug(f"История сообщений в конце запроса: messages: {messages}")
    return response_message, inf_for_user

API_DBM._answergpt_with_api = _answergpt_with_api

# %%
#@title Метод отправки обычного запроса без API
def _answergpt(self, all_messages):

    # Отправка запроса в GPT с поддержкой вызова функций
    response = openai.ChatCompletion.create(
        model = "gpt-3.5-turbo-0613",
        messages = all_messages,
        temperature = 1
    )
    # api_deb.debug (f"Ответ GPT:\n{response}")
    # Обработка ответа GPT

    content = response.choices[0].message

    return content

API_DBM._answergpt = _answergpt

# %%
#@title Метод формирования запроса для GPT
def get_response(self, user, with_api, save_hist=True, system=None):
    # Получаем текущую дату и время в часовом поясе GMT+7 и добавляем ее к сообщению
    if not self.user_goal: # Если конечная цель пользователя не задана. Задаём её.
        self.user_goal = user
    CURENT_TIME = datetime.now(timezone)
    user = f"{CURENT_TIME.strftime('%Y-%m-%d %H:%M')}: {user}"
    messages = self.messages # Подключаем историю переписки
    api_deb.info(f"Запрос в LLM user: {user}")
    api_deb.debug(f"messages в начале метода: {messages}")
    if messages == []: # Если история пустая (пришел первый запрос)
        if system:  # и системное сообщение задано, то
            system = f"{system}\n Цель сотрудника:{self.user_goal}"
            messages.append({"role": "system", "content": system}) # добавляем в историю заданное в параметрах системное сообщение,
        else:
            messages.append(self.system_basic) # иначе добавляем в нее базовое системное сообщение

    messages.append({"role": "user", "content": user}) # добавляем в историю сообщение пользователя
    api_deb.debug(f"messages до вызова _answergpt_with_api {messages}")

    if with_api:
        api_deb.debug(f"system: {system}")
        response_message, inf_for_user = self._answergpt_with_api(messages)
        api_deb.info(f"inf_for_user {inf_for_user}")
    else:
        response_message = self._answergpt(messages)
    api_deb.debug(f"messages после запроса _answergpt_with_api: {messages}")
    # Добавляем в историю переписки system, user,
    api_deb.debug(f"response_message: {response_message}")
    messages.append(response_message)

    if save_hist:
        self.messages = messages # перезаписываем историю текущего экземпляра класса
    api_deb.debug(f"История сообщений messages:\n {messages}")
    assistant_content = response_message["content"]
    return assistant_content

API_DBM.get_response = get_response

# %% [markdown]
# ## 5.3 Роли

# %%
#@title Роль при ответе API на анализ информации в интернете
system1 = """Ты бот, который помагает сотрудникам нашей компании получать доступ к функциям API
    Твоя задача получив запрос пользвателя, вызвать подходящую функцию, тщательно определив значения параметров.
    В случае получения успешного овтета от API - направить пользователю ответ.
    В случае получения неуспешного ответа от API, то попробуй сформировать новый запрос к API, доработав
    входные параметры. Если таких запросов стало более 5, сообщи пользователю о возникающей ошибке от API.
    В случае если данных для формирования запроса не хваратет, направь пользователю зарпос этих данных.
    Важно! Отвечай только преобразовав полученную от API информацию, не добавляй и не дополняй от себя"""


API_DBM.system_roles["internet_analysis"] = system1

# %%
#@title Роль аналитика поисковой выдачи Goggle одной страницы
system = """Ты помощник сотрудника нашей компании и эксперт в поиске нужной информации в интернете.
    Ты исключаешь нерелевантные результаты поисковой выдачи одной страницы Google, из тех, которые тебе направлены.
    Это необхоимо сделать, чтобы снизить дальнейшие трудозатраты на детальный анализ сайтов в поисковой выдаче.
    Твоя задача выбрать ответы Google, не релевантные запросу сотрудника. Для этого исходи из сути и цели его запроса.
    Не релевантные результаты:
    - спам
    - лишняя реклама
    - сайты-клоны
    - ответы не соответствующие сути и цели запроса - пусть даже там совпадают слова.
    В ответ вызови функцию remove_nonrelevant_results с номерами нерелевантных ответов. Если нерелевантны все ответы, укажи все номера.
    """

API_DBM.system_roles["remove_nonrelevant_results"] = system

system = """
    Ты получил ответ от системы. Он содержит несколько первых результатов поисковой выдачи на вопрос сотрудника.
    Составь развернутый ответ сотруднику на основании этой информации.
    Не перечисляй все данные поисковой выдачи. Система уже направила сотруднику результаты поисковой выдачи.
    Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос"""

API_DBM.system_roles["after_api_remove_nonrelevant_results"] = system

# %%
#@title Роль базовая BOT_HELPER_WITH_API
system1 = """Ты Бот, осуществляющий вызов функций API для решения вопросов сотрудников нашей компании.
    Ответы на вопросы сотрудников ты формируешь только на основании данных API.
    Первым делом определи, есть ли прямая команда к действию, которой соответствует функция API.
    Есил нет, выясни выясни цель. Возможно сотрудник имеет представление,
    каким способом он бы хотел решить свой вопрос. Предложи ему подходящий вариат из своей базы функций.
    Все это изложи в ответном сообщении сотруднику.
    Имея всю необходимую информацию вызови функцию API.
    Важно! Ты можешь пользоваться только вызовом функций и ты можешь спрашивать! Тебе запрещено давать ответы, взятые не по данным API!
    """

system2 = """Ты сотрудник глобальной справочной системы, который помагает сотрудникам нашей компании максимально точно отвечая на их запросы,
    а также выполнять различные задачи пользуясь функциями API.
    Твоя задача получив сообщение от сотрудника, определить каким из трех вариантов решения воспользоваться:
    1. Если сообщение содержит прямую задачу, и имеющейся в сообщении информации достаточно - вызови нужную функцию API.
    2. Если сообщение содержит прямую задачу, и имеющейся в сообщении информации не достаточно -
    вызови функцию запроса дополнительных данных .
    3. Если сообщение содержит запрос или вопрос, и в твоей базе имеется актуальный на дату запроса информация - ответь сотруднику сам.
    4. Если сообщение содержит запрос или вопрос, и в твоей базе отсутствует актуальная на дату запроса информация - вызови функцию API
    для получения данных из Интернета.
    Важно! Если ты отправляешь дозапрос - излагай супер кратко и привливо"""


func_desc_str = ""
for func_name in API_DBM.func_desc.keys():  # Перебираем все ключи (названия функций)
    func_desc_str = f"{func_desc_str}\n{API_DBM.func_desc[func_name]} | {API_DBM.func_result[func_name]} | {func_name}"
print(func_desc_str)  # Выводим информацию на экран
system3 = f"""Ты сотрудник глобальной справочной системы, который помагает сотрудникам нашей компании разделять их запрос
    на последовательную цепочку подзадач. В твоем распоряжении имеется каталог функций, которыми можно воспользоваться
    для решения запроса сотрудника. Одна функция может решить одну подзадачу.
    Составь последовательность подзадач, чтобы результат выполнения одной функции использовался в качестве
    входных данных следующей.
    Определи оптимальную последовательность подзадач руководствуясь здравой логикой.
    В запросе API пришли человеческое описание подзадачи как это сделал бы обычный человек.
    ВАЖНО! Рассчитай, сохрани в подзадаче все количественные показатели, и детали из исходного запроса. (Например, если нужно найти
    в интернете и далее проанализировать по 3 товара из 5 сайтов. То цифры 3 и 5 являются важными параметрами подзадач).

    Каталог функций в формате (Описание | Результат выполнения | name):{func_desc_str}"""

system4 = f"""Ты разработчик детальных планов и задач.
    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,
    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.
    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)
    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.
    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):{func_desc_str}"""

API_DBM.system_roles["BOT_HELPER_WITH_API"] = system4
# Out:
# Загрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders
# Загрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm
# Формирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search
# Анализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis
# Исключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.
# Обновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results
# Описание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions
# Осознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension

# %% [markdown]
# # 4 Выполнение

# %% [markdown]
# ## 4.1 Парсинг сайта Норникель

# %%
nornickelsite = NornickelSite()
nornickel_tenders = nornickelsite.download_tenders(2)
# Out:
# load_quantity 2
# total_pages = 18
# page = 1
# tenders_data = [{'name': 'Анонс 20027362/1: по выбору Поставщика на комплекс работ по выполнению инженерных изысканий, разработке проектной документации, поставке материально-технических ресурсов, выполнению строительно-монтажных и пуско-наладочных работ на условиях «под ключ»', 'activeTo': 1696107600, 'method': {'value': 'Анонс', 'xmlId': 'preview'}, 'previewText': 'Анонс ЗФ ПАО «ГМК «Норильский никель»&nbsp;по выбору Поставщика на\r\nкомплекс работ по выполнению инженерных изысканий, разработке проектной документации,\r\nпоставке материально-технических ресурсов, выполнению строительно-монтажных и\r\nпуско-наладочных работ на условиях «под&nbsp;ключ» проекта «НМЗ.&nbsp;Увеличение\r\nпропускной способности северной системы оборотного водоснабжения» /шифр&nbsp;НМЗ‑ССОВ/', 'customer': {'value': 'Заполярный филиал ПАО "ГМК "Норильский никель"', 'description': ''}, 'address': {'value': 'г. Норильск', 'description': ''}, 'organizer': {'value': 'Заполярный транспортный филиал', 'description': ''}, 'email': {'value': 'Kichiginsv@nornik.ru; MatovichVS@nornik.ru', 'description': ''}, 'phone': {'value': '+7 (3919) 25-37-20, +7 (3919) 25-67-59', 'description': ''}, 'applicationMethod': {'value': 'В электронной форме отправка по адресу эл. Почты Организатора', 'xmlId': 'digital_on_address'}, 'documentation': {'link': '/upload/iblock/95e/wkhf6kpzmm63g543wzr2674lp4dt14vm/TZ.pdf', 'name': '', 'size': '3.73 МБ', 'type': 'pdf'}}, {'name': '20027343/1 Выполнение научно-исследовательской работы «Определение параметров проветривания рудника «Заполярный» ', 'activeTo': 1694725200, 'method': {'value': 'Запрос предложений', 'xmlId': 'offers_req'}, 'previewText': '', 'customer': {'value': 'ООО "НН Девелопмент"', 'description': ''}, 'address': {'value': '', 'description': ''}, 'organizer': {'value': 'ООО «НН Девелопмент»', 'description': ''}, 'email': {'value': '', 'description': ''}, 'phone': {'value': '', 'description': ''}, 'applicationMethod': {'value': 'В Системе управления закупками SRM Норникель', 'xmlId': 'procurement_system'}, 'documentation': {'link': '/upload/iblock/d65/fotzw5w82wmu88fokmnt9m3h217tstlx/Priglashenie-na-uchastie-v-zakupochnoy-protsedure.zip', 'name': '', 'size': '591.61 КБ', 'type': 'zip'}}, {'name': '20027343/1: Выполнение НИР (параметры проветривания): Выполнение научно-исследовательской работы «Определение параметров проветривания рудника «Заполярный» при существующих способе и схеме проветривания и производительности по добыче 1200 тыс. тонн руды в', 'activeTo': 1694638800, 'method': {'value': 'Запрос предложений', 'xmlId': 'offers_req'}, 'previewText': '', 'customer': {'value': ' ПАО "ГМК "Норильский никель"', 'description': ''}, 'address': {'value': 'г. Москва', 'description': ''}, 'organizer': {'value': ' ПАО &quot;ГМК &quot;Норильский никель&quot;', 'description': ''}, 'email': {'value': 'KUZNETSOVDSERG@NORNIK.RU', 'description': ''}, 'phone': {'value': '', 'description': ''}, 'applicationMethod': {'value': 'В Системе управления закупками SRM Норникель', 'xmlId': 'procurement_system'}, 'documentation': {'link': '/upload/iblock/a17/xojta3h0v8rgkqt1njx3fu778nz74iut/Dokumenty-i-prilozheniya2023_08_25_06_34_26.zip', 'name': '', 'size': '591.68 КБ', 'type': 'zip'}}, {'name': '143862 Закупка запчастей для ТО Урал, КамАЗ БС', 'activeTo': 1694552400, 'method': {'value': 'Запрос цен', 'xmlId': 'prices_req'}, 'previewText': '', 'customer': {'value': 'ООО "НН Технические Сервисы"', 'description': ''}, 'address': {'value': 'г. Санкт-Петербург Гражданский проспект, д. 11', 'description': ''}, 'organizer': {'value': 'НН Технические Сервисы', 'description': ''}, 'email': {'value': 'oozao@nornik.ru', 'description': ''}, 'phone': {'value': '+7 (981) 698-09-73', 'description': ''}, 'applicationMethod': {'value': 'В электронной форме отправка по адресу эл. Почты Организатора', 'xmlId': 'digital_on_address'}, 'documentation': {'link': '/upload/iblock/36a/6sumub2fzo8c2wb2zeliw9gny7y6me4z/143862.zip', 'name': '', 'size': '4.82 МБ', 'type' ...
# Количество тендеров: 2

# %% [markdown]
# ## 4.2 Создание экземпляров PurchaseFiles, загрузка файлов в папку URL и разархивирование

# %%
#@title Создание экземпляров PurchaseFiles
purchases_files = {}
for tender_id, tender_data in nornickel_tenders.items():
    purchases_files[tender_id] = tender_data.create_purchase_files()
    print(f"Создан экземпляр PurchaseFiles {purchases_files[tender_id].id}")

# %%
#@title Загрузка файлов в папку URL

# Проход по всем элементам в словаре purchases_files
for purchase_id, purchase_file_obj in purchases_files.items():

    try:
        purchase_file_obj.download_files()  # Запуск метода download_files для каждого объекта PurchaseFiles
        print(f"Загрузка файлов для тендера с ID {purchase_id} завершена.")  # Опционально: вывод информационного сообщения
    except RuntimeError as e:
        print(f"Не удалось загрузить файл по URL {url}. Ошибка: {e}")

# %%
#@title Распаковка файлов из папки URL в папку UnPack

# Проход по всем элементам в словаре purchases_files
for purchase_id, purchase_file_obj in purchases_files.items():
    purchase_file_obj.process_files()  # Запуск метода download_files для каждого объекта PurchaseFiles
    print(f"Распаковка файлов для тендера с ID {purchase_id} завершена.")  # Опционально: вывод информационного сообщения

# %% [markdown]
# ## 4.3 Создание документов Document и разспознование содержания

# %%
#@title Создание Документов на основе Файлов

all_documents = {}

# Перебор файлов в папке UnPack и запуск create_documents для каждого seldonid
for seldon_id, one_purchase_files in purchases_files.items():
    purchase_documents = one_purchase_files.create_documents()

    all_documents.update(purchase_documents)

# %%
#@title Чтение контента

level = "Стандартный" #["Поверхностный", "Стандартный", "Детальный"]
# Итерация по всем элементам словаря documents
for id, purchase_documents in all_documents.items():
    for doc_name, document in purchase_documents.items():
        # Вызов метода find_specification для текущего объекта Document
        if document.read_file_content(level) == True:
            print(f"Получен контент документа {document.name}")
        else:
            print(f"Не получен контент документа {document.name}")
            print(f"Контент: {document.content}")

# %%
#@title Разделелние контента на чати

# Итерация по всем элементам словаря documents
for id, purchase_documents in all_documents.items():
    for doc_name, document in purchase_documents.items():
        # Вызов метода split_content_into_parts для текущего объекта Document
        if document.content:
            # print(document.content)
            document.split_content_into_parts()
            print("___________")

# %%
#@title Осмысление частей контента

# Итерация по всем элементам словаря documents
for id, purchase_documents in all_documents.items():
    for doc_name, document in purchase_documents.items():
        # Вызов метода split_content_into_parts для текущего объекта Document
        if document.content_parts:
            # print(document.content)
            document.parts_abstract()
            print("___________")

# %%
#@title Осмысление документа

# Итерация по всем элементам словаря documents
for id, purchase_documents in all_documents.items():
    for doc_name, document in purchase_documents.items():
        # Вызов метода split_content_into_parts для текущего объекта Document
        if document.about_parts:
            # print(document.content)
            document.document_meaning()
            print("___________")

# %%
#@title Просмотр осмысленного описания документа

# Итерация по всем элементам словаря documents
for id, purchase_documents in all_documents.items():
    for doc_name, document in purchase_documents.items():
        # Вызов метода split_content_into_parts для текущего объекта Document
        if document.about_content:
            print(f"Для тендера {document.tender_id} документ {document.name}: \n{document.about_content}")

# %% [markdown]
# ## 4.4 Работа с архивом в Google Drive

# %%
#@title Архивирование
# archive = DataBase('/content/drive/My Drive/archive_google_colab.pkl')
archive = DataBase('/content/drive/My Drive/CRM_DataBase.pkl')


archive.add_data(api_dbm.inf_for_user, "NornickelTender")
#archive.add_data(purchases_files, "PurchaseFiles")
#archive.add_data(all_documents, "Document")

# Сохранение архива на диск (например, Google Drive)
archive.save()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-79-80149e56f0a5> in <cell line: 3>()
#       1 #@title Архивирование
#       2 # archive = DataBase('/content/drive/My Drive/archive_google_colab.pkl')
# ----> 3 archive = DataBase('/content/drive/My Drive/CRM_DataBase.pkl')
#       4
#       5
#
# <ipython-input-14-e96f0074bd7e> in __init__(self, file_path)
#       7         self.file_path = file_path
#       8         with open(self.file_path, 'rb') as input_file:
# ----> 9             database = pickle.load(input_file)
#      10         return database
#
# EOFError: Ran out of input

# %%
#@title Загрузка данных с диска
# Загрузка архива с диска
loaded_DataBase = DataBase.get_data('/content/drive/My Drive/archive_google_colab.pkl')

nornickel_tenders_archive = loaded_archive.NornickelTender_db
purchases_files = loaded_archive.PurchaseFiles_db
all_documents = loaded_archive.Document_db

# Вывод количества загруженных экземпляров в каждом классе
print(f"Загружено nornickel_tenders_archive: {len(nornickel_tenders_archive)}")
print(f"Загружено PurchaseFiles: {len(purchases_files)}")
print(f"Загружено Document: {len(all_documents)}")
# Out:
# Загружено nornickel_tenders_archive: 10
# Загружено PurchaseFiles: 10
# Загружено Document: 3

# %%
#@title Просмотр содержания архива

# Итерация по всем элементам словаря documents
for id, nornickel_tender_archive in nornickel_tenders_archive.items():
    print (f"Состав архива {nornickel_tender_archive.id}: Дата:{nornickel_tender_archive.active_to} {nornickel_tender_archive.name}")

# %% [markdown]
# ## 4.5 Работа с API и LLM

# %%
user_message = "Загрузи в CRM 3 тендера"
function_name = ["chain_actions"]
with_api = True
api_dbm = API_DBM(function_name, True)
api_dbm.get_response(user_message, with_api)
# Out:
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в начале запроса: messages: [{'role': 'system', 'content': "Ты разработчик детальных планов и задач.\n    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,\n    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.\n    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)\n    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.\n    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):\nЗагрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders\nЗагрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm\nФормирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search\nАнализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis\nИсключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.\nОбновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results\nОписание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions\nОсознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension"}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузи в CRM 3 тендера'}]
# API_DEBUG(DEBUG) _answergpt_with_api: Объявленная API для LLM: list(self.available_api.values()): [{'name': 'chain_actions', 'description': 'Описание цепочки подзадач', 'parameters': {'type': 'object', 'properties': {'top_task': {'type': 'string', 'description': 'Исходная (верхнеуровневая) задача пользователя'}, 'subtasks': {'type': 'array', 'items': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': 'Описание подзадачи на человеческом языке с вниманием к деталям'}, 'name': {'type': 'string', 'enum': ['nornickel_tenders', 'load_to_crm', 'google_search', 'internet_analysis', 'remove_nonrelevant_results'], 'description': 'Кодовое имя соответствующей возможности'}}, 'required': ['name', 'question']}, 'description': 'Список подзадач, в порядке их выполнения'}}, 'required': ['top_task']}}]
# API_DEBUG(INFO) _answergpt_with_api: 1. API ОБРАБОТЧИК НАЙДЕН: chain_actions, аргументы: {'top_task': 'Загрузка тендеров в CRM', 'subtasks': [{'action': 'Загрузка тендеров с сайта Норникеля', 'name': 'nornickel_tenders'}, {'action': 'Загрузка данных в CRM из кэша пользователя', 'name': 'load_to_crm'}]}
#
# 04.09.23 02:16 Нейросеть: Определяю план действий...
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в начале запроса: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузка тендеров с сайта Норникеля'}]
# API_DEBUG(DEBUG) _answergpt_with_api: Объявленная API для LLM: list(self.available_api.values()): [{'name': 'nornickel_tenders', 'description': 'Загрузка тендеров с сайта Норникеля', 'parameters': {'type': 'object', 'properties': {'load_quantity': {'type': 'integer', 'description': 'Количество закупок, которые необходимо загрузить'}, 'page_number': {'type': 'integer', 'description': "Номер страницы для загрузки данных, при указании параметра 'load_volume'='PAGE'"}}}}]
# API_DEBUG(INFO) _answergpt_with_api: 3. API ОБРАБОТЧИК НАЙДЕН: nornickel_tenders, аргументы: {'load_quantity': 3}
#
# 04.09.23 02:16 Нейросеть: Загружаю закупки с сайта Норникель...
# 04.09.23 02:16 Нейросеть: Найден тендер с именем: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024)
# 04.09.23 02:16 Нейросеть: Активно до: 14.09.2023
# 04.09.23 02:16 Нейросеть: Метод: Конкурс только для СМиСП
# 04.09.23 02:16 Нейросеть: Заказчик: АО " НТЭК"
# 04.09.23 02:16 Нейросеть: Адрес: ул. Ветеранов,19
# 04.09.23 02:16 Нейросеть: Организатор: НТЭК
# 04.09.23 02:16 Нейросеть: Email: KazimirskiyAV@oao-ntek.ru,
# 04.09.23 02:16 Нейросеть: Телефон: 7 (3919) 25-94-59
# 04.09.23 02:16 Нейросеть: Метод подачи заявки: В электронной форме на Электронной торговой площадке
# 04.09.23 02:16 Нейросеть: Документация: https://www.nornickel.ru/upload/iblock/60a/zhniv1qme7k8r7s6hh2302h7ag1fianh/lot-204_23.rar
# 04.09.23 02:16 Нейросеть: Тип документации: rar
# 04.09.23 02:16 Нейросеть: ------
# 04.09.23 02:16 Нейросеть: Найден тендер с именем: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23
# 04.09.23 02:16 Нейросеть: Активно до: 14.09.2023
# 04.09.23 02:16 Нейросеть: Метод: Конкурс только для СМиСП
# 04.09.23 02:16 Нейросеть: Заказчик: АО "НТЭК"
# 04.09.23 02:16 Нейросеть: Адрес:
# 04.09.23 02:16 Нейросеть: Организатор: НТЭК
# 04.09.23 02:16 Нейросеть: Email:
# 04.09.23 02:16 Нейросеть: Телефон:
# 04.09.23 02:16 Нейросеть: Метод подачи заявки: В электронной форме на Электронной торговой площадке
# 04.09.23 02:16 Нейросеть: Документация: https://www.nornickel.ru/upload/iblock/c13/qnlsp3038fbo8vbkghzuislmv0nh1qj3/211_23.rar
# 04.09.23 02:16 Нейросеть: Тип документации: rar
# 04.09.23 02:16 Нейросеть: ------
# 04.09.23 02:16 Нейросеть: Найден тендер с именем: 20027346/1 Поставка цементно-песчаной смести М100
# 04.09.23 02:16 Нейросеть: Активно до: 14.09.2023
# 04.09.23 02:16 Нейросеть: Метод: Анонс
# 04.09.23 02:16 Нейросеть: Заказчик: ООО "НН Девелопмент"
# 04.09.23 02:16 Нейросеть: Адрес:
# 04.09.23 02:16 Нейросеть: Организатор: ООО «НН Девелопмент»
# 04.09.23 02:16 Нейросеть: Email: KuznetsovDserg@nornik.ru
# 04.09.23 02:16 Нейросеть: Телефон:
# 04.09.23 02:16 Нейросеть: Метод подачи заявки: В электронной форме отправка по адресу эл. Почты Организатора
# 04.09.23 02:16 Нейросеть: Документация: https://www.nornickel.ru/upload/iblock/3ce/c1szfojaanb3wguxtugejgvlcmm9pndb/Anons-na-uchastie-v-zakupochnoy-protsedure.zip
# 04.09.23 02:16 Нейросеть: Тип документации: zip
# 04.09.23 02:16 Нейросеть: ------
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений перед добавлением в message_history: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузка тендеров с сайта Норникеля'}]
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений после добавления в message_history: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузка тендеров с сайта Норникеля'}, <OpenAIObject at 0x7bde3dd52660> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "nornickel_tenders",
#     "arguments": "{\n  \"load_quantity\": 3\n}"
#   }
# }]
# LLM_TO_LLM(INFO) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: Успешно. Сотруднику представлена информация о 3 тендерах с сайта Норникель.
#     Тендеры c вложенными документами загружены в кэш пользователя 'content_comprehension' под номерами [('Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024)', '14.09.2023'), ('Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23', '14.09.2023'), ('20027346/1 Поставка цементно-песчаной смести М100', '14.09.2023')]
# LLM_TO_LLM(DEBUG) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузка тендеров с сайта Норникеля'}, <OpenAIObject at 0x7bde3dd52660> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "nornickel_tenders",
#     "arguments": "{\n  \"load_quantity\": 3\n}"
#   }
# }, {'role': 'function', 'name': 'nornickel_tenders', 'content': "Успешно. Сотруднику представлена информация о 3 тендерах с сайта Норникель.\n    Тендеры c вложенными документами загружены в кэш пользователя 'content_comprehension' под номерами [('Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024)', '14.09.2023'), ('Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23', '14.09.2023'), ('20027346/1 Поставка цементно-песчаной смести М100', '14.09.2023')]"}, {'role': 'system', 'content': "\n        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.\n        Кроме того обязательно спроси сотрудника, нужно ли тебе заняться осознанием содержания загруженных\n        тендеров. Эти данные сохраняются в кэш пользователя 'content_comprehension'.\n        Вероятнее всего он попросит тебя загрузить их в CRM (функция load_to_crm).\n        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры."}]
# LLM_TO_LLM(INFO) _answergpt_with_api: Ответ LLM пользователю: Успешно. Я загрузил информацию о 3 тендерах с сайта Норникель. Данные тендеров сохранены в кэш пользователя 'content_comprehension' под следующими номерами:
# 1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023
# 2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023
# 3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023
#
# Теперь я могу загрузить эти тендеры в CRM. Пожалуйста, подтвердите, что вам нужно их загрузить в CRM.
# LLM_TO_LLM(DEBUG) _answergpt_with_api: response_message: {
#   "role": "assistant",
#   "content": "\u0423\u0441\u043f\u0435\u0448\u043d\u043e. \u042f \u0437\u0430\u0433\u0440\u0443\u0437\u0438\u043b \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u044e \u043e 3 \u0442\u0435\u043d\u0434\u0435\u0440\u0430\u0445 \u0441 \u0441\u0430\u0439\u0442\u0430 \u041d\u043e\u0440\u043d\u0438\u043a\u0435\u043b\u044c. \u0414\u0430\u043d\u043d\u044b\u0435 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0441\u043e\u0445\u0440\u0430\u043d\u0435\u043d\u044b \u0432 \u043a\u044d\u0448 \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044f 'content_comprehension' \u043f\u043e\u0434 \u0441\u043b\u0435\u0434\u0443\u044e\u0449\u0438\u043c\u0438 \u043d\u043e\u043c\u0435\u0440\u0430\u043c\u0438:\n1. \u0422\u0435\u043d\u0434\u0435\u0440: \u041f\u0440\u0430\u0432\u043e \u0437\u0430\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u044f \u0440\u0430\u043c\u043e\u0447\u043d\u043e\u0433\u043e \u0434\u043e\u0433\u043e\u0432\u043e\u0440\u0430 \u043f\u043e\u0434\u0440\u044f\u0434\u0430 \u043d\u0430 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435 \u0440\u0430\u0431\u043e\u0442 \u043f\u043e \u0440\u0435\u043c\u043e\u043d\u0442\u0443 \u0441\u0442\u0435\u043d\u043e\u0432\u043e\u0433\u043e \u043e\u0433\u0440\u0430\u0436\u0434\u0435\u043d\u0438\u044f \u043d\u0430 \u043e\u0431\u044a\u0435\u043a\u0442\u0430\u0445 \u0422\u042d\u0426-2 \u0410\u041e \u00ab\u041d\u0422\u042d\u041a\u00bb \u043b\u043e\u0442 \u2116 204/23 (\u0422\u042d\u0426-2/\u0417\u0438\u0421/4-2024), \u0414\u0430\u0442\u0430: 14.09.2023\n2. \u0422\u0435\u043d\u0434\u0435\u0440: \u041a\u043e\u043d\u043a\u0443\u0440\u0441 \u0432 \u044d\u043b\u0435\u043a\u0442\u0440\u043e\u043d\u043d\u043e\u0439 \u0444\u043e\u0440\u043c\u0435, \u0443\u0447\u0430\u0441\u0442\u043d\u0438\u043a\u0430\u043c\u0438 \u043a\u043e\u0442\u043e\u0440\u043e\u0433\u043e \u043c\u043e\u0433\u0443\u0442 \u0431\u044b\u0442\u044c \u0442\u043e\u043b\u044c\u043a\u043e \u0421\u041c\u0421\u041f, \u043d\u0430 \u043f\u0440\u0430\u0432\u043e \u0437\u0430\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u044f \u0440\u0430\u043c\u043e\u0447\u043d\u043e\u0433\u043e \u0434\u043e\u0433\u043e\u0432\u043e\u0440\u0430 \u043f\u043e\u0434\u0440\u044f\u0434\u0430 \u043d\u0430 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435 \u0440\u0430\u0431\u043e\u0442 \u043f\u043e \u0440\u0435\u043c\u043e\u043d\u0442\u0443 \u043a\u043e\u043d\u0441\u0442\u0440\u0443\u043a\u0446\u0438\u0438 \u043a\u0440\u043e\u0432\u043b\u0438 \u0413\u043b\u0430\u0432\u043d\u043e\u0433\u043e \u043a\u043e\u0440\u043f\u0443\u0441\u0430 \u0422\u042d\u0426-2 \u0410\u041e \u00ab\u041d\u0422\u042d\u041a\u00bb, \u043b\u043e\u0442 \u2116 211/23, \u0414\u0430\u0442\u0430: 14.09.2023\n3. \u0422\u0435\u043d\u0434\u0435\u0440: 20027346/1 \u041f\u043e\u0441\u0442\u0430\u0432\u043a\u0430 \u0446\u0435\u043c\u0435\u043d\u0442\u043d\u043e-\u043f\u0435\u0441\u0447\u0430\u043d\u043e\u0439 \u0441\u043c\u0435\u0441\u0442\u0438 \u041c100, \u0414\u0430\u0442\u0430: 14.09.2023\n\n\u0422\u0435\u043f\u0435\u0440\u044c \u044f \u043c\u043e\u0433\u0443 \u0437\u0430\u0433\u0440\u0443\u0437\u0438\u0442\u044c \u044d\u0442\u0438 \u0442\u0435\u043d\u0434\u0435\u0440\u044b \u0432 CRM. \u041f\u043e\u0436\u0430\u043b\u0443\u0439\u0441\u0442\u0430, \u043f\u043e\u0434\u0442\u0432\u0435\u0440\u0434\u0438\u0442\u0435, \u0447\u0442\u043e \u0432\u0430\u043c \u043d\u0443\u0436\u043d\u043e \u0438\u0445 \u0437\u0430\u0433\u0440\u0443\u0437\u0438\u0442\u044c \u0432 CRM."
# }
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в конце запроса: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузка тендеров с сайта Норникеля'}, <OpenAIObject at 0x7bde3dd52660> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "nornickel_tenders",
#     "arguments": "{\n  \"load_quantity\": 3\n}"
#   }
# }, {'role': 'function', 'name': 'nornickel_tenders', 'content': "Успешно. Сотруднику представлена информация о 3 тендерах с сайта Норникель.\n    Тендеры c вложенными документами загружены в кэш пользователя 'content_comprehension' под номерами [('Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024)', '14.09.2023'), ('Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23', '14.09.2023'), ('20027346/1 Поставка цементно-песчаной смести М100', '14.09.2023')]"}, {'role': 'system', 'content': "\n        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.\n        Кроме того обязательно спроси сотрудника, нужно ли тебе заняться осознанием содержания загруженных\n        тендеров. Эти данные сохраняются в кэш пользователя 'content_comprehension'.\n        Вероятнее всего он попросит тебя загрузить их в CRM (функция load_to_crm).\n        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры."}]
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в начале запроса: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:17: Загрузка данных в CRM из кэша пользователя'}]
# API_DEBUG(DEBUG) _answergpt_with_api: Объявленная API для LLM: list(self.available_api.values()): [{'name': 'load_to_crm', 'description': 'Загрузка данных в CRM из кэша пользователя', 'parameters': {'type': 'object', 'properties': {'cache_name': {'type': 'string', 'enum': ['nornickel_tenders', 'documents'], 'description': 'Имя кэша пользователя'}}, 'required': ['cache_name']}}]
# API_DEBUG(INFO) _answergpt_with_api: 3. API ОБРАБОТЧИК НАЙДЕН: load_to_crm, аргументы: {'cache_name': 'nornickel_tenders'}
#
# 04.09.23 02:17 Нейросеть: Загружаю данные в CRM...
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений перед добавлением в message_history: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:17: Загрузка данных в CRM из кэша пользователя'}]
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений после добавления в message_history: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:17: Загрузка данных в CRM из кэша пользователя'}, <OpenAIObject at 0x7bde3dd0a250> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "load_to_crm",
#     "arguments": "{\n  \"cache_name\": \"nornickel_tenders\"\n}"
#   }
# }]
# LLM_TO_LLM(INFO) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])
# LLM_TO_LLM(DEBUG) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:17: Загрузка данных в CRM из кэша пользователя'}, <OpenAIObject at 0x7bde3dd0a250> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "load_to_crm",
#     "arguments": "{\n  \"cache_name\": \"nornickel_tenders\"\n}"
#   }
# }, {'role': 'function', 'name': 'load_to_crm', 'content': "Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])"}, {'role': 'system', 'content': '\n        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.\n        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры.'}]
# LLM_TO_LLM(INFO) _answergpt_with_api: Ответ LLM пользователю: Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])
# LLM_TO_LLM(DEBUG) _answergpt_with_api: response_message: {
#   "role": "assistant",
#   "content": "\u0423\u0441\u043f\u0435\u0445. \u0414\u0430\u043d\u043d\u044b\u0435 \u0438\u0437 'nornickel_tenders' \u043f\u0440\u0435\u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043d\u044b \u0438 \u0437\u0430\u0433\u0440\u0443\u0436\u0435\u043d\u044b \u0432 CRM. \u0422\u0438\u043f \u0434\u0430\u043d\u043d\u044b\u0445: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])"
# }
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в конце запроса: messages: [{'role': 'system', 'content': 'Сформируй запрос к API по задаче пользователя.\n    При формировании параметров запроса ориентируйся на задачу пользователя и его цель.\n    Цель пользователя: Загрузи в CRM 3 тендера\n    \n Цель сотрудника:Загрузи в CRM 3 тендера'}, {'role': 'user', 'content': '2023-09-04 09:17: Загрузка данных в CRM из кэша пользователя'}, <OpenAIObject at 0x7bde3dd0a250> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "load_to_crm",
#     "arguments": "{\n  \"cache_name\": \"nornickel_tenders\"\n}"
#   }
# }, {'role': 'function', 'name': 'load_to_crm', 'content': "Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])"}, {'role': 'system', 'content': '\n        # Ты получил ответ от системы. Если он Успешный, сообщи о нем сотруднику, не добавляя ничего от себя.\n        # Если же ошибка, ты можешь повторить запрос, выбрав более точно параметры.'}]
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений перед добавлением в message_history: messages: [{'role': 'system', 'content': "Ты разработчик детальных планов и задач.\n    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,\n    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.\n    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)\n    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.\n    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):\nЗагрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders\nЗагрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm\nФормирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search\nАнализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis\nИсключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.\nОбновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results\nОписание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions\nОсознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension"}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузи в CRM 3 тендера'}]
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений после добавления в message_history: messages: [{'role': 'system', 'content': "Ты разработчик детальных планов и задач.\n    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,\n    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.\n    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)\n    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.\n    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):\nЗагрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders\nЗагрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm\nФормирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search\nАнализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis\nИсключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.\nОбновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results\nОписание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions\nОсознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension"}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузи в CRM 3 тендера'}, <OpenAIObject at 0x7bde3dd52890> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "chain_actions",
#     "arguments": "{\n  \"top_task\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0432 CRM\",\n  \"subtasks\": [\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0441 \u0441\u0430\u0439\u0442\u0430 \u041d\u043e\u0440\u043d\u0438\u043a\u0435\u043b\u044f\",\n      \"name\": \"nornickel_tenders\"\n    },\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0434\u0430\u043d\u043d\u044b\u0445 \u0432 CRM \u0438\u0437 \u043a\u044d\u0448\u0430 \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044f\",\n      \"name\": \"load_to_crm\"\n    }\n  ]\n}"
#   }
# }]
# LLM_TO_LLM(INFO) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: . Результат выполнения 'nornickel_tenders': Успешно. Я загрузил информацию о 3 тендерах с сайта Норникель. Данные тендеров сохранены в кэш пользователя 'content_comprehension' под следующими номерами:
# 1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023
# 2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023
# 3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023
#
# Теперь я могу загрузить эти тендеры в CRM. Пожалуйста, подтвердите, что вам нужно их загрузить в CRM.. Результат выполнения 'load_to_crm': Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])
# LLM_TO_LLM(DEBUG) _answergpt_with_api: Запрос без API в LLM для ответа пользователю: [{'role': 'system', 'content': "Ты разработчик детальных планов и задач.\n    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,\n    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.\n    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)\n    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.\n    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):\nЗагрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders\nЗагрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm\nФормирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search\nАнализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis\nИсключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.\nОбновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results\nОписание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions\nОсознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension"}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузи в CRM 3 тендера'}, <OpenAIObject at 0x7bde3dd52890> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "chain_actions",
#     "arguments": "{\n  \"top_task\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0432 CRM\",\n  \"subtasks\": [\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0441 \u0441\u0430\u0439\u0442\u0430 \u041d\u043e\u0440\u043d\u0438\u043a\u0435\u043b\u044f\",\n      \"name\": \"nornickel_tenders\"\n    },\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0434\u0430\u043d\u043d\u044b\u0445 \u0432 CRM \u0438\u0437 \u043a\u044d\u0448\u0430 \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044f\",\n      \"name\": \"load_to_crm\"\n    }\n  ]\n}"
#   }
# }, {'role': 'function', 'name': 'chain_actions', 'content': ". Результат выполнения 'nornickel_tenders': Успешно. Я загрузил информацию о 3 тендерах с сайта Норникель. Данные тендеров сохранены в кэш пользователя 'content_comprehension' под следующими номерами:\n1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023\n2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023\n3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023\n\nТеперь я могу загрузить эти тендеры в CRM. Пожалуйста, подтвердите, что вам нужно их загрузить в CRM.. Результат выполнения 'load_to_crm': Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])"}, {'role': 'system', 'content': '\n        Ты получил ответ в виде списка результатов по каждой выполненной функции. Данные по каждой функции выведены сотруднику.\n        Твоя задача сформировать итоговое заключение по задаче пользователя. И попросить его дать обратную связь, правильно ли\n        была подобрана стратегия. Всех необходимые данные находятся в кэше пользователя.\n        Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос'}]
# LLM_TO_LLM(INFO) _answergpt_with_api: Ответ LLM пользователю: Задача "Загрузи в CRM 3 тендера" была успешно выполнена. Я загрузил информацию о 3 тендерах с сайта Норникель и преобразовал их данные для загрузки в CRM. Тендеры были сохранены в кэш пользователя 'content_comprehension' под следующими номерами:
# 1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023
# 2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023
# 3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023
#
# Данные были успешно загружены в CRM со следующими ID: [10004, 10005, 10006].
#
# Пожалуйста, проверьте в CRM, что тендеры были корректно загружены и укажите, если есть дополнительные задачи или требуется что-то дополнительное. Буду рад помочь!
#
# Спасибо за обратную связь! Пожалуйста, поделитесь вашим мнением о предложенной стратегии и работе, чтобы мы могли улучшить наши процессы.
# LLM_TO_LLM(DEBUG) _answergpt_with_api: response_message: {
#   "role": "assistant",
#   "content": "\u0417\u0430\u0434\u0430\u0447\u0430 \"\u0417\u0430\u0433\u0440\u0443\u0437\u0438 \u0432 CRM 3 \u0442\u0435\u043d\u0434\u0435\u0440\u0430\" \u0431\u044b\u043b\u0430 \u0443\u0441\u043f\u0435\u0448\u043d\u043e \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u0430. \u042f \u0437\u0430\u0433\u0440\u0443\u0437\u0438\u043b \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u044e \u043e 3 \u0442\u0435\u043d\u0434\u0435\u0440\u0430\u0445 \u0441 \u0441\u0430\u0439\u0442\u0430 \u041d\u043e\u0440\u043d\u0438\u043a\u0435\u043b\u044c \u0438 \u043f\u0440\u0435\u043e\u0431\u0440\u0430\u0437\u043e\u0432\u0430\u043b \u0438\u0445 \u0434\u0430\u043d\u043d\u044b\u0435 \u0434\u043b\u044f \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u0438 \u0432 CRM. \u0422\u0435\u043d\u0434\u0435\u0440\u044b \u0431\u044b\u043b\u0438 \u0441\u043e\u0445\u0440\u0430\u043d\u0435\u043d\u044b \u0432 \u043a\u044d\u0448 \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044f 'content_comprehension' \u043f\u043e\u0434 \u0441\u043b\u0435\u0434\u0443\u044e\u0449\u0438\u043c\u0438 \u043d\u043e\u043c\u0435\u0440\u0430\u043c\u0438:\n1. \u0422\u0435\u043d\u0434\u0435\u0440: \u041f\u0440\u0430\u0432\u043e \u0437\u0430\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u044f \u0440\u0430\u043c\u043e\u0447\u043d\u043e\u0433\u043e \u0434\u043e\u0433\u043e\u0432\u043e\u0440\u0430 \u043f\u043e\u0434\u0440\u044f\u0434\u0430 \u043d\u0430 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435 \u0440\u0430\u0431\u043e\u0442 \u043f\u043e \u0440\u0435\u043c\u043e\u043d\u0442\u0443 \u0441\u0442\u0435\u043d\u043e\u0432\u043e\u0433\u043e \u043e\u0433\u0440\u0430\u0436\u0434\u0435\u043d\u0438\u044f \u043d\u0430 \u043e\u0431\u044a\u0435\u043a\u0442\u0430\u0445 \u0422\u042d\u0426-2 \u0410\u041e \u00ab\u041d\u0422\u042d\u041a\u00bb \u043b\u043e\u0442 \u2116 204/23 (\u0422\u042d\u0426-2/\u0417\u0438\u0421/4-2024), \u0414\u0430\u0442\u0430: 14.09.2023\n2. \u0422\u0435\u043d\u0434\u0435\u0440: \u041a\u043e\u043d\u043a\u0443\u0440\u0441 \u0432 \u044d\u043b\u0435\u043a\u0442\u0440\u043e\u043d\u043d\u043e\u0439 \u0444\u043e\u0440\u043c\u0435, \u0443\u0447\u0430\u0441\u0442\u043d\u0438\u043a\u0430\u043c\u0438 \u043a\u043e\u0442\u043e\u0440\u043e\u0433\u043e \u043c\u043e\u0433\u0443\u0442 \u0431\u044b\u0442\u044c \u0442\u043e\u043b\u044c\u043a\u043e \u0421\u041c\u0421\u041f, \u043d\u0430 \u043f\u0440\u0430\u0432\u043e \u0437\u0430\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u044f \u0440\u0430\u043c\u043e\u0447\u043d\u043e\u0433\u043e \u0434\u043e\u0433\u043e\u0432\u043e\u0440\u0430 \u043f\u043e\u0434\u0440\u044f\u0434\u0430 \u043d\u0430 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435 \u0440\u0430\u0431\u043e\u0442 \u043f\u043e \u0440\u0435\u043c\u043e\u043d\u0442\u0443 \u043a\u043e\u043d\u0441\u0442\u0440\u0443\u043a\u0446\u0438\u0438 \u043a\u0440\u043e\u0432\u043b\u0438 \u0413\u043b\u0430\u0432\u043d\u043e\u0433\u043e \u043a\u043e\u0440\u043f\u0443\u0441\u0430 \u0422\u042d\u0426-2 \u0410\u041e \u00ab\u041d\u0422\u042d\u041a\u00bb, \u043b\u043e\u0442 \u2116 211/23, \u0414\u0430\u0442\u0430: 14.09.2023\n3. \u0422\u0435\u043d\u0434\u0435\u0440: 20027346/1 \u041f\u043e\u0441\u0442\u0430\u0432\u043a\u0430 \u0446\u0435\u043c\u0435\u043d\u0442\u043d\u043e-\u043f\u0435\u0441\u0447\u0430\u043d\u043e\u0439 \u0441\u043c\u0435\u0441\u0442\u0438 \u041c100, \u0414\u0430\u0442\u0430: 14.09.2023\n\n\u0414\u0430\u043d\u043d\u044b\u0435 \u0431\u044b\u043b\u0438 \u0443\u0441\u043f\u0435\u0448\u043d\u043e \u0437\u0430\u0433\u0440\u0443\u0436\u0435\u043d\u044b \u0432 CRM \u0441\u043e \u0441\u043b\u0435\u0434\u0443\u044e\u0449\u0438\u043c\u0438 ID: [10004, 10005, 10006].\n\n\u041f\u043e\u0436\u0430\u043b\u0443\u0439\u0441\u0442\u0430, \u043f\u0440\u043e\u0432\u0435\u0440\u044c\u0442\u0435 \u0432 CRM, \u0447\u0442\u043e \u0442\u0435\u043d\u0434\u0435\u0440\u044b \u0431\u044b\u043b\u0438 \u043a\u043e\u0440\u0440\u0435\u043a\u0442\u043d\u043e \u0437\u0430\u0433\u0440\u0443\u0436\u0435\u0 ...
# }
# API_DEBUG(DEBUG) _answergpt_with_api: История сообщений в конце запроса: messages: [{'role': 'system', 'content': "Ты разработчик детальных планов и задач.\n    Сотрудник нашей компании просит тебя выполнить его запрос. Твоя задача представить его задачу в виде последовательности подзадач,\n    с помощью каталога наших возможностей, не упустив ни малейшей детали в запросе сотрудника.\n    Критерием твоей качественной работы является внимание к мелочайшим деталям зарпоса (числовым значениям, прилагательным)\n    В ответном сообщении пришли запрос chain_actions с текстовым описанием подзадач и имени возможности, сформулированных тобой детально.\n    Каталог наших возможностей (Описание | Результат выполнения | Имя возможности):\nЗагрузка тендеров с сайта Норникеля | Тендеры с описанием и документами загружены в кэш пользователя 'nornickel_tenders' | nornickel_tenders\nЗагрузка данных в CRM из кэша пользователя | Данные из кэша пользователя загружены в CRM | load_to_crm\nФормирование поисковой выдачи Google | Результат поисковой выдачи загружен в кэш пользователя 'google_search' | google_search\nАнализ информации в интернете (до 10 мин) | Осозанный результат поисковой выдачи сообщен пользователю, а поисковая выдача загружена в кэш пользователя 'internet_analysis' | internet_analysis\nИсключение ответов поисковой выдачи Google, нерелевантных сути запроса и цели | Из кэша пользователя 'google_search' исключены значения, нерелевантные зарпосу.\nОбновленная поисковая выдача помещена в кэш пользвателя 'remove_nonrelevant_results' | remove_nonrelevant_results\nОписание цепочки подзадач | Выполнена цепочка подзадач, итоговый результат выполнения помещен в кэш пользователя 'chain_actions' | chain_actions\nОсознание содержания элементов CRM | Элементы CRM с осознанным GPT содержанием сохранены в CRM и загружены в кэш пользователя 'content_comprehension' | content_comprehension"}, {'role': 'user', 'content': '2023-09-04 09:16: Загрузи в CRM 3 тендера'}, <OpenAIObject at 0x7bde3dd52890> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "chain_actions",
#     "arguments": "{\n  \"top_task\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0432 CRM\",\n  \"subtasks\": [\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0442\u0435\u043d\u0434\u0435\u0440\u043e\u0432 \u0441 \u0441\u0430\u0439\u0442\u0430 \u041d\u043e\u0440\u043d\u0438\u043a\u0435\u043b\u044f\",\n      \"name\": \"nornickel_tenders\"\n    },\n    {\n      \"action\": \"\u0417\u0430\u0433\u0440\u0443\u0437\u043a\u0430 \u0434\u0430\u043d\u043d\u044b\u0445 \u0432 CRM \u0438\u0437 \u043a\u044d\u0448\u0430 \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u0435\u043b\u044f\",\n      \"name\": \"load_to_crm\"\n    }\n  ]\n}"
#   }
# }, {'role': 'function', 'name': 'chain_actions', 'content': ". Результат выполнения 'nornickel_tenders': Успешно. Я загрузил информацию о 3 тендерах с сайта Норникель. Данные тендеров сохранены в кэш пользователя 'content_comprehension' под следующими номерами:\n1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023\n2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023\n3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023\n\nТеперь я могу загрузить эти тендеры в CRM. Пожалуйста, подтвердите, что вам нужно их загрузить в CRM.. Результат выполнения 'load_to_crm': Успех. Данные из 'nornickel_tenders' преобразованы и загружены в CRM. Тип данных: 'crm_tenders', crm_id:dict_keys([10004, 10005, 10006])"}, {'role': 'system', 'content': '\n        Ты получил ответ в виде списка результатов по каждой выполненной функции. Данные по каждой функции выведены сотруднику.\n        Твоя задача сформировать итоговое заключение по задаче пользователя. И попросить его дать обратную связь, правильно ли\n        была подобрана стратегия. Всех необходимые данные находятся в кэше пользователя.\n        Важно! Не дублируй результаты выдачи, а составь ответ на его вопрос'}]
# 'Задача "Загрузи в CRM 3 тендера" была успешно выполнена. Я загрузил информацию о 3 тендерах с сайта Норникель и преобразовал их данные для загрузки в CRM. Тендеры были сохранены в кэш пользователя \'content_comprehension\' под следующими номерами:\n1. Тендер: Право заключения рамочного договора подряда на выполнение работ по ремонту стенового ограждения на объектах ТЭЦ-2 АО «НТЭК» лот № 204/23 (ТЭЦ-2/ЗиС/4-2024), Дата: 14.09.2023\n2. Тендер: Конкурс в электронной форме, участниками которого могут быть только СМСП, на право заключения рамочного договора подряда на выполнение работ по ремонту конструкции кровли Главного корпуса ТЭЦ-2 АО «НТЭК», лот № 211/23, Дата: 14.09.2023\n3. Тендер: 20027346/1 Поставка цементно-песчаной смести М100, Дата: 14.09.2023\n\nДанные были успешно загружены в CRM со следующими ID: [10004, 10005, 10006].\n\nПожалуйста, проверьте в CRM, что тендеры были корректно загружены и укажите, если есть дополнительные задачи или требуется что-то дополнительное. Буду рад помочь!\n\nСпасибо за обратную связь! Пожалуйста, поделитесь вашим мнением о предложенной стратегии и работе, чтобы мы могли улучшить наши процессы.'

# %%
user_message = "Осознай контент загруженных тендеров 10007, 10008,  10009"
api_dbm.get_response(user_message, with_api)

# %% [markdown]
# # 5 Тесты

# %% [markdown]
#  ## Установка библиотек

# %%
# !pip install scrapy scrapy-selenium beautifulsoup4

# %% [markdown]
# ## Методы

# %%
#@title Объявление класса MySpider и его методы
MySpider_code = """
import logging
import scrapy
from scrapy_selenium import SeleniumRequest
from scrapy.crawler import CrawlerProcess
from bs4 import BeautifulSoup


class MySpider(scrapy.Spider):
    name = 'myspider'
    start_urls = ['https://s-materials.ru']  # Начальная страница

    def start_requests(self):
        for url in self.start_urls:
            yield SeleniumRequest(url=url, callback=self.parse, wait_time=1000)  # Увеличьте время ожидания по вашему усмотрению


    def parse(self, response):
        # Добавьте ваш код для работы с динамическими элементами с использованием response.driver
        page_content = response.body

        # Используем BeautifulSoup для извлечения текста
        soup = BeautifulSoup(page_content, 'html.parser')
        visible_text = soup.get_text()

        # Выводим видимый текст
        print(visible_text)
"""

# %%
#@title Выгрузка класса MySpider и исполняемого кода в файл
runner_code = """
from scrapy.crawler import CrawlerProcess
import logging

# Код класса MySpider
from myspider import MySpider


if __name__ == '__main__':
    process = CrawlerProcess(settings={
        'LOG_LEVEL': 'ERROR',  # Устанавливаем уровень логирования
        'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7'  # Устанавливаем версию отпечатка запроса
    })

    process.crawl(MySpider)
    process.start()

"""

with open('runner.py', 'w') as f:
    f.write(runner_code)

with open('myspider.py', 'w') as f:
    f.write(MySpider_code)

# %%
#@title Запуск исполняемого файла Парсинга
# !python runner.py
# Out:
# С-МАТЕРИАЛСWe're sorry but s-materials doesn't work properly without JavaScript enabled. Please enable it to continue.

# %%
url = 'https://s-materials.ru'
url = 'https://www.vseinstrumenti.ru/category/stroitelnye-kleschi-i-schiptsy-4243/?ysclid=lltuudm452318366338'

# %%
# !pip install jsbeautifier

# %%
#@title Расшифровка обфусцированного скрипта
import jsbeautifier
from selenium import webdriver

logging.getLogger('selenium').setLevel(logging.CRITICAL)
logging.getLogger('urllib3').setLevel(logging.CRITICAL)



chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"')
chrome_options.add_argument('--window-size=1920,1080')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-extensions')
chrome_options.add_argument('--disable-images')

browser = webdriver.Chrome(options=chrome_options)


# Открываем страницу

browser.get(url)

# Получаем текст зашифрованного JavaScript
encrypted_js = browser.execute_script("return document.documentElement.innerHTML")

# Деобфусцируем код с помощью js-beautify
beautified_js = jsbeautifier.beautify(encrypted_js)

# Выводим деобфусцированный код
print(beautified_js)

# Закрываем браузер
browser.quit()

# %%
#@title Метод парсинга страницы и получения html
import re
import logging
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pprint
# Устанавливаем уровень журналирования

logging.getLogger('selenium').setLevel(logging.CRITICAL)
logging.getLogger('urllib3').setLevel(logging.CRITICAL)



chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"')
chrome_options.add_argument('--window-size=1920,1080')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-extensions')
chrome_options.add_argument('--disable-images')

browser = webdriver.Chrome(options=chrome_options)



# Открываем страницу

browser.get(url)

# Получаем HTML-код страницы
html = browser.page_source
browser.quit()

# %%
#@title Просмотр текста страницы
# Открываем страницу
url = 'https://s-materials.ru'
browser.get(url)
# Создаем список для хранения вывода
output = []

# Используем XPath для извлечения блоков
blocks = browser.find_elements(By.XPATH, '//div[@class="your-block-class"]')

# Перебираем блоки
for block in blocks:
    # Извлекаем текст из блока
    block_text = block.find_element(By.XPATH, './div[@class="text-class"]').text

    # Извлекаем ссылку из блока
    block_link = block.find_element(By.XPATH, './a[@class="link-class"]')
    link_text = block_link.text
    link_href = block_link.get_attribute('href')

    # Добавляем текст и ссылку в список вывода
    output.append(f"Text: {block_text}")
    output.append(f"Link: {link_text} - {link_href}")

# Закрываем браузер
browser.quit()

# Выводим содержимое списка
for line in output:
    print(line)

# %%
#@title Метод очистки лишней инфомрации с html
def clean_and_display_html(html, base_url):
    # Первый этап: замена неполных выражений типа href на полноценные ссылки
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.find_all('a', href=True):
        href = a_tag.get('href')
        if href.startswith('/') and not href.startswith('//'):
            a_tag['href'] = f'{base_url}{href}'

        a_tag.string = f'"{a_tag.get_text(strip=True)}" ({a_tag.get("href")})'

    # Второй этап: исключение всех атрибутов
    for tag in soup.find_all(True):
        tag.attrs = {}

    # Третий этап: удаление "террад" из тэгов
    terrad_pattern = re.compile(r'<[^>]*>')
    for tag in soup.find_all(True):
        tag_str = str(tag)
        tag_str = re.sub(terrad_pattern, '', tag_str)
        tag.clear()
        tag.append(tag_str)

    # Выводим очищенный HTML
    print(soup.prettify())

clean_and_display_html(html, url)
# Out:
# <!DOCTYPE html>
# <html>
#  Just a moment...Enable JavaScript and cookies to continue(function(){window._cf_chl_opt={cvId: '2',cZone: 'www.vseinstrumenti.ru',cType: 'managed',cNounce: '69464',cRay: '7fd717a96e5f1d6a',cHash: '81420b309dc8d66',cUPMDTk: "\/category\/stroitelnye-kleschi-i-schiptsy-4243\/?ysclid=lltuudm452318366338&amp;__cf_chl_tk=SoeQv_Q9jjxSaeBSlPPI.bIL2nmV18FwJT5k3MtF8W0-1693168436-0-gaNycGzNCzs",cFPWv: 'g',cTTimeMs: '1000',cMTimeMs: '0',cTplV: 5,cTplB: 'cf',cK: "",fa: "/category/stroitelnye-kleschi-i-schiptsy-4243/?ysclid=lltuudm452318366338&amp;amp;__cf_chl_f_tk=SoeQv_Q9jjxSaeBSlPPI.bIL2nmV18FwJT5k3MtF8W0-1693168436-0-gaNycGzNCzs",md: "Gv3psq7ADWNOz6opvGJVHOCI0BBbUMFtRKQviuxvxGI-1693168436-0-AarbzRFduP83RBGHUozMPwXTFo3EmWNUX-Lb1Sh3TbKYzFUxtuRsLhrX318PufcBzpC-cstEhtVn9vKX5mL-qxsD7rAga6aA_ujtnplK41-TaRkVf_WQ3RROMz_nxkQERWlfzOSw6pFNsjK8zkdo2eBugU0W0gCgkJrxUo1dJs9ZANsvwPZHw57tLcIYOVJBE6h_yH1nF7WUlXzFIii-GVgxNen_SdEREkBALu_KLhp5wQfCE2I1YOl7iZNV0IWi_azr31CYcQbrHqo3E68XTxicVmclbdRlAnTLQj70CJAoEZPENt_m9Efrw75I8KNzp1xj2gFwsh5jOo5lPn-usFxReMHJHTBOkEtQaGmDZ6Rlwfp7aqE7S4aImE8Fb0k8gnGDZUghDOPHnn_n7MPYKZd-h4u9FjYW9g1vV3DvVzi15aUdy1zPDiP7acJIDx8D1atpcPAP_eWKeH9iS7AFF1s2Pr2oOZWff1ohD0DPIu8ArQ-ceZ59qf3CAgVtB36esrfTOdpIdLdEehb8rx1eGFU-G_kO2McAd2KtixpgXIoTmVPM3GA1mnBoEpktMUywztUxK1WKavg6IPFCxZSTlec2jOd1yXUZkSkLT1Q_FbqX-XxlYc3RZATdjUA86qFd8Z1vb9MkZCnkYpM6SUf2tP-xICPqWxx3k3ZGY20K9_daig6Zuiy98B2N4sHJZlHpY4C4xqRVeWxcCQfSMw0xH37qKDCtcKnRkNR-qX1fFCB9j_T4Mif_LtZY-T8gdlcL_i5YP4D45VRCyoWlhqaXX5NtR75KKCEiQdAfzAUubLh1dLMoW_cZ47EhtTpCn0xjsBcoWEy783HsCwb-gAEpPgft3e2l_T1IO-cxeeT-jp20yISVqXIcsfmtk5s6djjq4-IQqR6HqbziDMLI8nsYRPkIS8_uK9WEkIQRKq594OySZpFYEwosdPwePhgA5sCqay-xfLe7gMNEK-jBfBFDIEGJ3G2d5oCRLIrj-8TcqftezIY58kBQ7JraEjj3jJuuDFhqByVdaGZB_IHfxjkN90XZ3_VOfY60RvAxg8yXbZDJ1jPD-Hts3YirDJAPc7C292P83EQTHDBuPRksKehKAOLBHtKPlM3LH7kXPMZ53Z7iZ3FRY-6DSnHMMaxHXLvIkJlvCaDuKyKCRdqBcrxY4aXPciy7-lIGanu57i5V5O3J3AQXskhO1A1IPxzWxHSYnn6gvC2rmiPzKlQttnWJMu3V8TGYCMQMsDQi94wlC9ksJn6SUq3o-6P3Fc31I47v1a_WqAiw1JOmqOFgnqzMc6rKPx5OT_F_qfxrKhijCk72hj50Sw0MBmQYhvz63vXnjuZYwrzKtZF0bs5VpWAyh0iQKDHJUa7HmzQqSYkrLj5Tuim4yFrFM5MWUjBw1NqvJMZonpa37LoaN-tN6dd_bgOVO9ALr3yhcZmClnORMMT_SwM6eB4td2bwkMGNobhmXW63do_aECeE7MkPmBz-ADu-XerHqWJkC6Aytnt2Y0mGQNSOoHMDmV3OHmLBX3bNznmoWHPicF__HSiozT6tA_JN-CYAfSouW2ed16g12t2a0HUXaL-9Bm6QfkS8iVwbJ53flsLSs0Sl72A604UT2CLv9PSqsl04lbU6LwSPsf-QYGsoQMZME-m2EpQdJo4OCv7I9j7dkGxTMAWgFb-90uqaReV3pxMUQpJ-RH_d8MN0bqRPikUgAQnOXD-fSNLbhA_H4Ixz6FpIzLRzFI3WhPiP0pdghkmRHmNtOShHkvzMcxjnxmKHd19KiAf50C6Xes5AULvLvN7Vt3KXWHHnio0LTNNWazL697WCdy2qEPwWVjom0ul8lVbC0HTI22-r0ZB1bF2WLk-jDRVlc5zvwfVRafQlipt0_C6JxgVWFXC_ALI0TwbE3VcYNkN3ruzaHpxRb05Q-wxREzcigOeyUZPUzRxGuC1ikfYpgoE-9zhap8YY5dVZdPZtxy6gNHp5gTDKU2oQXZXGzvsBWxNN1Cf3imYbAknkIoAYQwFX66hxPHKKErh90h-yw-_LALlrdXNRfW-HMHoVe_VtgmU49CW4lrOoxyhgz1desUpwuA5hhBqxEIvf9RQcylvYsCy6zqOJExUfoAdMWxRK3evw8MhCpQDWSxK46qYsXoz6Gw_yJ3DlZ_IbrwJMR_iw73KNXw8iLphUR1OFAzXyiK33TwvxrB0gKJzGSDPR65Nr99VCtQOxqY0przBQvuyMV8t-TYlrgj99kJWYpHQofYJPlk_hosRB6-bFPaMXyUiH5sKxk37P3p2hELsdjnhadWcEjoGQk_gsj9zfV4hkoVJ5plFFzkWvS7INoG-eaH6KLomQTvvhj8oTJJlTT_79osHobQC2Y6bh7n-UNrV4Zh6ACZ2o6ywiHtof9ZLQGkglZsG4YHfOjJR4ysLyApKFHfE1F4yQNemlGz83jyttb33Px2QY7PkzXTqyyi1g2FzTP3IWipwxFIKxWO-RZleuEyah7yF-PQXCcTBYvXyfeRVWjhZY9kcKYiGCOaKriTNYJ-QjOqOETIr-8k3gbdbQOKNVoVE-byWq87vv1r0YRwSCEdkUFcUwwF-lJNxDNIDQx0AXt6U_aUhSgIs-ec2Apom0V18mFSwUN4CYqPDGkEnxgWShsnOKC32PWCsLzQ_CTll7DjfpKbwIeVbBy5gvpMOPpPDZZgimqe6hDpVUzOIzRgi8E-R4up9RKMqPPbT2CAi_v0sb5z-RpX23OW5fBg0pHVflYHDORyXvjE1QLJ-pQtoVKcuNpKN_M7NZu0gKlonhKrcNUZb4sUMomj1stZP3kQ",cRq: {ru: 'aHR0cHM6Ly93d3cudnNlaW5zdHJ1bWVudGkucnUvY2F0ZWdvcnkvc3Ryb2l0ZWxueWUta2xlc2NoaS1pLXNjaGlwdHN5LTQyNDMvP3lzY2xpZD1sbHR1dWRtNDUyMzE4MzY2MzM4',ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMzEuMA==',rm: 'R0VU',d: '...',t: 'MTY5MzE2ODQzNi43MTIwMDA=',cT: Math.floor(Date.now() / 1000),m: 'HKWCNKGUtcyMQWVqi5IXJ8zeQ+y6eoj3s0u7mjYzR3k=',i1: 'UD4fjGvOLPPjzXXyFgP8PQ==',i2: 'U0wH8ZSDSE7Oj5B8JvXeaA==',zh: 'ii/2WDdRZKVg4JcFqLKAddIht7KCiERS9jsaUHRlQ6U=',uh: 'YE9XOpG5TeHmhA1zfs5mxC8CrRZzq2a/+r+OU7dliYQ=',hh: ...
# </html>

# %%
print(html)

# %%
# !pip install mitmproxy
# !apt-get install -y libfontconfig1 libxrender1

# %%
pip install --upgrade mitmproxy

# %%
# !mitmproxy --mode reverse:url@8082 --set keep_host_header

# %%
# !pip uninstall mitmproxy -y
# !pip install mitmproxy

# %%
# !pip show mitmproxy

# %%
import requests
import os
from mitmproxy import proxy, options
from mitmproxy.tools.dump import DumpMaster
from mitmproxy import http
from mitmproxy import options
config = proxy.ProxyConfig(opts)


class InterceptRequests:
    def __init__(self):
        self.num = 0

    def response(self, flow: http.HTTPFlow) -> None:
        self.num += 1
        print(f"Intercepted response {self.num}")
        print("URL:", flow.request.url)
        print("Method:", flow.request.method)
        print("Headers:", flow.request.headers)
        print("Content:", flow.response.content)
        print("=" * 50)


def start_proxy():
    opts = options.Options(listen_host='0.0.0.0', listen_port=8080, http2=True)
    config = ProxyConfig(opts)
    state = DumpMaster(opts, with_termlog=False, with_dumper=False)

    try:
        state.run()
    except KeyboardInterrupt:
        state.shutdown()

start_proxy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-504-c1d38543ed17> in <cell line: 7>()
#       5 from mitmproxy import http
#       6 from mitmproxy import options
# ----> 7 config = proxy.ProxyConfig(opts)
#       8
#       9
#
# AttributeError: module 'mitmproxy.proxy' has no attribute 'ProxyConfig'

# %% [markdown]
# ## Тест

# %%
#@title Обновление файла из репозитория GIT HUB
import git

# Путь к папке, где ранее был склонирован репозиторий
local_folder = 'colab_repo'

# Создаем объект Repo
repo = git.Repo(local_folder)

# Выполняем команду git pull
repo.remotes.origin.pull()

# %% [markdown]
# # 1 Работа с тендерами SELDON

# %% [markdown]
# ## 1.1 Методы

# %%
#@title Импорт библиотек

import requests #Для выполнения HTTP-запросов к API
import time # для установления срока действия ключа
import os # Для работы с файловой системой
import zipfile # распаковка файлов (архивов)
import shutil # Для операций над файлами и директориями.

# %%
#@title Объявление класса
class Seldon:
    def __init__(self, base_url, username, password):
        self.base_url = base_url
        self.username = username
        self.password = password
        self.token = None
        self.token_expiration = 0
        self.seldon_ids = [] # Список для хранения seldonid, по которым произошла успешная выгрузка файлов.
        self.orders = {} # Словарь для хранения списка созданных в Seldon заказов по каждому фильтру.
        self.documents = {}         # Словарь для хранения списков документов по seldonid
        self.files = {}  # Словарь для хранения списка загруженных файлов
        self.folders = {} # Словарь для хранения путей к папкам UnPack, Spec, Temp по seldonid

    def _request(self, method, endpoint, data=None):
        headers = {
            "Authorization": f"Bearer {self.token}" if self.token else None,
            "Content-Type": "application/json"
        }

        url = self.base_url + endpoint
        response = requests.request(method, url, json=data, headers=headers)

        return response

    def authenticate(self):
        url = "/User/Login"
        data = {
            "name": self.username,
            "password": self.password
        }

        response = self._request("POST", url, data)

        if response.status_code == 200:
            result = response.json()
            self.token = result["result"]["token"]
            self.token_expiration = time.time() + 86400  # Устанавливаем время истечения токена (24 часа)
            print("Авторизация успешна. Токен получен.")
        else:
            print("Ошибка авторизации. Код статуса:", response.status_code)

    #Проверка срока действия токена
    def check_token(self):
        if self.token_expiration < time.time():
            print("Токен устарел. Обновляем.")
            self.authenticate()

# %%
#@title Методы загрузки документов в папку URL

# Получение фильтров
def get_filters(self):
    url = "/User/Filters?token=" + self.token
    response = self._request("POST", url)

    if response.status_code == 200:
        result = response.json()
        filters = result["result"]["filters"]
        return filters
    else:
        print("Ошибка получения фильтров. Код статуса:", response.status_code)
        return None

Seldon.get_filters = get_filters

#Проверка баланса
def get_balance(self):
    url = "/User/Balance?token=" + self.token
    response = self._request("POST", url)

    if response.status_code == 200:
        result = response.json()

        print("Дата начала действия лицензии:", result["result"]["licenseStart"])
        print("Дата окончания действия лицензии:", result["result"]["licenseEnd"])
        for entry in result["result"]["databalance"]:
            print(f"Тип лимита: {entry['type']}")
            print(f"Лимит на количество новых объектов: {entry['newlimit']}")
            print(f"Остаток новых объектов: {entry['newbalance']}")
            print(f"Суточный лимит на количество объектов: {entry['daylimit']}")
            print(f"Остаток объектов за сутки: {entry['daybalance']}")
            print()
        else:
            print("Ошибка получения баланса. Код статуса:", response.status_code)
            return None

Seldon.get_balance = get_balance

#Создание заказа на выгрузку информации
def create_order(self, type, filter_id, date_from, date_to, subtype=None):
    url = f"/{type}/New?token=" + self.token
    data = {
        "filterId": filter_id,
        "dateFrom": date_from,
        "dateTo": date_to,
        "subtype": subtype
    }

    response = self._request("POST", url, data)

    if response.status_code == 200:
        result = response.json()

        # Проверяем код статуса внутри JSON
        status_code = result.get('status', {}).get('code')
        status_description = result.get('status', {}).get('descr')

        if status_code == 200:
            task_id = result["result"]["taskId"]
            print(f"Заказ {task_id} успешно создан.")
            self.orders[filter_id] = task_id
            return task_id
        else:
            print(f"Ошибка: {status_description}")
            return None
    else:
        print(f"Ошибка создания заказа. HTTP код статуса: {response.status_code}")
        return None

Seldon.create_order = create_order

#Получение SeldonId закупок
def get_purchases_seldon_ids(self, task_id, page_index):
    result = self.get_purchases_result(task_id, page_index)
    if 'result' in result and isinstance(result['result'], list):
        seldon_ids = [item['SeldonId'] for item in result['result']]
        # print("Список SeldonId:", seldon_ids)
    else:
        print("Ключ 'result' не найден или он не является списком.")

    return seldon_ids

Seldon.get_purchases_seldon_ids = get_purchases_seldon_ids

# Запрос на выгрузку списка закупок по заказу
def get_purchases_result(self, task_id, page_index):
    url = f"/purchases/result?token=" + self.token
    data = {
        "taskId": task_id,
        "pageIndex": page_index
    }

    response = self._request("POST", url, data)

    if response.status_code == 200:
        result = response.json()
        print(f"Список закупок {result}")
        return result
    else:
        print("Ошибка получения результата по закупкам. Код статуса:", response.status_code)
        return None

Seldon.get_purchases_result = get_purchases_result

#Получение списка документов
def get_purchases_documents(self, reportId, seldonid):
    url = f"/purchasesdocuments/get?token=" + self.token
    data = {
        "reportId": reportId, #тип закупки
        "seldonId": seldonid #Идентификатор закупки в Seldon
    }

    response = self._request("POST", url, data)

    if response.status_code == 200:
        result = response.json()

        # Проверяем код статуса внутри JSON
        status_code = result.get('status', {}).get('code')
        status_description = result.get('status', {}).get('descr')

        if status_code == 200:
            # Сохраняем полученный список документов по Seldon ID
            self.documents[seldonid] = result
            print(f"Список документов сохранен в атрибуте documents под SeldonID = {seldonid}")
            return result
        else:
            print(f"Ошибка: Код {status_code}: {status_description}")
            self.documents[seldonid] = None
            return None
    else:
        print(f"Ошибка получения результата по закупкам. HTTP код статуса: {response.status_code}")
        return None

Seldon.get_purchases_documents = get_purchases_documents

# Функция загрузки и сохранения файла по url
def download_and_save_file(self, url, seldonid):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        folder_path = os.path.join("Downloads", str(seldonid), "URL")
        os.makedirs(folder_path, exist_ok=True)
        filename = os.path.join(folder_path, f"{os.path.basename(url)}")
        with open(filename, "wb") as file:
            file.write(response.content)
        print(f"Файл успешно загружен и сохранен как {filename}.")
        self.files[seldonid] = self.files.get(seldonid, []) + [filename]

        # Добавление seldonid в список self.seldon_ids, если его там еще нет
        if seldonid not in self.seldon_ids:
            self.seldon_ids.append(seldonid)
    else:
        print(f"Ошибка при загрузке файла. Код ответа: {response.status_code}")

Seldon.download_and_save_file = download_and_save_file

# Метод загрузки и сохранения файлов по Seldon ID
def download_purchases_documents(self, seldonid):
    # Очищаем список файлов для конкретного seldonid
    if seldonid in self.files:
        self.files[seldonid] = []

    if seldonid in self.documents and self.documents[seldonid] is not None:
        # Проверка на наличие статуса 404 в ответе
        status = self.documents[seldonid].get('status', {})
        if status.get('code') == 404:
            print(status.get('descr', 'Ошибка не описана'))
            return

        documents = self.documents[seldonid].get("result", {}).get("purchasesdocuments", [])
        for doc in documents:
            urlSources = doc.get("documents", [])
            if urlSources:
                if isinstance(urlSources, list):
                    for i, doc_data in enumerate(urlSources):
                        urlSource = doc_data.get("urlSource")
                        if urlSource:
                            self.download_and_save_file(urlSource, seldonid)
                else:
                    urlSource = urlSources.get("urlSource")
                    if urlSource:
                        self.download_and_save_file(urlSource, seldonid)
            else:
                print(f"Для документа с id={doc['id']} отсутствует ссылка на файл.")
    else:
        print(f"Документы с Seldon ID={seldonid} не найдены.")

Seldon.download_purchases_documents = download_purchases_documents

# %% [markdown]
# ## 1.2 Выполнение

# %%
#@title Инициирование, задание ID закупки

# Пример использования
if __name__ == "__main__":
    base_url = "https://apitorgi.myseldon.com"
    username = "Test2461035432"
    password = "33Hk25R0"

    seldon_api = Seldon(base_url, username, password)

    seldon_api.authenticate()
    seldon_api.check_token()

    # Теперь у вас есть токен, который будет использоваться при повторных запросах к API


seldonid = 1054240840
reportId = 3
filterId = 4301475
# Out:
# Авторизация успешна. Токен получен.

# %%
#@title Загрузка документов по закупке в папку URL

#seldon_api.get_purchases_result(3, 1)
seldon_ids = [1054240841, 1054240842, 1054240800, 1054240840]
for seldon_id in seldon_ids:
    # Получение списка документов для загрузке по SeldonID
    seldon_api.get_purchases_documents(reportId, seldon_id)

    # Загрузка списка файлов с Seldon по seldonid, загрузка файлов с ЭТП в папку URL
    seldon_api.download_purchases_documents(seldon_id)

# seldon_api.print_files(seldonid) #вывод на экран списка загруженных файлов
# Out:
# Список документов сохранен в атрибуте documents под SeldonID = 1054240841
# Файл успешно загружен и сохранен как Downloads/1054240841/URL/Dokumenty-i-prilozheniya2023_07_04_06_49_11.zip.
# Список документов сохранен в атрибуте documents под SeldonID = 1054240842
# Файл успешно загружен и сохранен как Downloads/1054240842/URL/Dokumenty-i-prilozheniya2023_07_04_06_45_22.zip.
# Ошибка: Код 404: Запрошенный идентификатор закупки отсутствует в БД
# Документы с Seldon ID=1054240800 не найдены.
# Список документов сохранен в атрибуте documents под SeldonID = 1054240840
# Файл успешно загружен и сохранен как Downloads/1054240840/URL/Dokumenty-i-prilozheniya2023_07_04_06_52_59.zip.

# %% [markdown]
# ### 1.2.1 Отключены ❌

# %%
#@title Создание заказа на выгрузку по ID фильтра (Временно отключено)

filter_id = 4301475
date_from = "2021-07-01T00:00:00.000Z"  # Дата начала интервала (30 дней назад от текущей даты)
date_to = "2021-07-31T23:59:59.999Z"    # Текущая дата

# Создаем заказ на получение информации по найденным закупкам за последние 30 дней по фильтру №4301475
# seldon_api.create_order("purchases", filter_id, date_from, date_to)
# order_id = seldon_api.orders[filter_id]
# print(f"ID заказа: {order_id}")

# %%
#@title Получение списка закупок по фильтру (временно отключено)

filter_id = 4301475
# orderid = seldon_api.orders[filter_id]
orderid = "1a1cab7e-24b9-44b1-8cd3-5437578feeef"

#print(seldon_api.get_purchases_result(orderid,1))


#print(seldon_api.get_purchases_seldon_ids(orderid,1))
